# %%
import pandas as pd

# %% [markdown]
# ## Join conformed table with imports table

# %%
df_hhi_production_egsehi = pd.read_csv("../data/hhi_production_exports_egsehi_conformed_table.csv")
final_imports_df = pd.read_csv("../data/imports_consolidated/imports_consolidated.csv")

# %%
# Lets select "important" columns
# columns = [
#     "period", "reporterCode", "reporterISO", "reporterDesc", "flowDesc",
#     "partnerCode", "partnerISO", "partnerDesc", "classificationSearchCode",
#     "cmdCode", "cmdDesc", "qty", "netWgt", 
#     "qtyUnitAbbr", "cifvalue", "primaryValue"
# ]
columns = [
    "period", "reporterCode",
    "partnerCode", "partnerISO", "partnerDesc",
    "cmdCode", "qty", "netWgt", 
    "qtyUnitAbbr", "cifvalue", "primaryValue", 
    "netWgt_total_import", "cifvalue_total_import", "primaryValue_total_import"
]
final_imports_df = final_imports_df[columns]
final_imports_df.rename(
    columns={
        "period": "Year",
        "partnerCode": "partnerCode_import",
        "partnerISO": "partnerISO_import",
        "partnerDesc": "partnerDesc_import",
        "qty": "qty_import",
        "netWgt": "netWgt_import",
        "qtyUnitAbbr": "qtyUnitAbbr_import",
        "cifvalue": "cifvalue_import",
        "primaryValue": "primaryValue_import"
    }, inplace=True)

final_imports_df
# Out:
#         Year  reporterCode  partnerCode_import partnerISO_import  \
# 0       2000            32                   0               W00
# 1       2000            32                 156               CHN
# 2       2000            36                 842               USA
# 3       2000            36                 360               IDN
# 4       2000            36                 710               ZAF
# ...      ...           ...                 ...               ...
# 420096  2020           894                   0               W00
# 420097  2020           894                 380               ITA
# 420098  2020           894                 710               ZAF
# 420099  2020           716                 710               ZAF
# 420100  2020           716                   0               W00
#
#        partnerDesc_import classificationSearchCode  cmdCode  qty_import  \
# 0                   World                       HS   261710      5000.0
# 1                   China                       HS   261710      5000.0
# 2                     USA                       HS   261710      1080.0
# 3               Indonesia                       HS   261710        56.0
# 4            South Africa                       HS   261710      1000.0
# ...                   ...                      ...      ...         ...
# 420096              World                       HS   261510     63000.0
# 420097              Italy                       HS   261510     30000.0
# 420098       South Africa                       HS   261510     33000.0
# 420099       South Africa                       HS   261510         0.0
# 420100              World                       HS   261510         0.0
#
#         netWgt_import qtyUnitAbbr_import  cifvalue_import  \
# 0              5000.0                 kg         8081.000
# 1              5000.0                 kg         8081.000
# 2              1080.0                 kg         2090.000
# 3                56.0                 kg        12691.000
# 4              1000.0                 kg         1756.000
# ...               ...                ...              ...
# 420096        63000.0                 kg        26944.376
# 420097        30000.0                 kg         9204.315
# 420098        33000.0                 kg        17740.061
# 420099            0.0                NaN       845145.046
# 420100            0.0                NaN       845145.046
#
#         primaryValue_import  netWgt_total_import  cifvalue_total_import  \
# 0                  8081.000               5000.0               8081.000
# 1                  8081.000               5000.0               8081.000
# 2                  2090.000               2136.0              16538.000
# 3                 12691.000               2136.0              16538.000
# 4                  1756.000               2136.0              16538.000
# ...                     ...                  ...                    ...
# 420096            26944.376              63000.0              26944.376
# 420097             9204.315              63000.0              26944.376
# 420098            17740.061              63000.0              26944.376
# 420099           845145.046                  0.0             845145.046
# 420100           845145.046                  0.0             845145.046
#
#         primaryValue_total_import
# 0                        8081.000
# 1                        8081.000
# 2                       16538.000
# 3                       16538.000
# 4                       16538.000
# ...                           ...
# 420096                  26944.376
# 420097                  26944.376
# 420098                  26944.376
# 420099                 845145.046
# 420100                 845145.046
#
# [420101 rows x 15 columns]

# %%
df_hhi_production_egsehi
# Out:
#        Year             Country  Domestic Production Value (P_AC)    Product  \
# 0      1970             ALBANIA                               NaN  ALUMINIUM
# 1      1971             ALBANIA                               NaN  ALUMINIUM
# 2      1972             ALBANIA                               NaN  ALUMINIUM
# 3      1973             ALBANIA                               NaN  ALUMINIUM
# 4      1974             ALBANIA                               NaN  ALUMINIUM
# ...     ...                 ...                               ...        ...
# 69784  2016  RUSSIAN FEDERATION                      5.584791e+08  PETROLEUM
# 69785  2017  RUSSIAN FEDERATION                      5.585467e+08  PETROLEUM
# 69786  2018  RUSSIAN FEDERATION                      5.678849e+08  PETROLEUM
# 69787  2019  RUSSIAN FEDERATION                      5.733888e+08  PETROLEUM
# 69788  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
#
#       ISO3  value_economic no_value_economic  value_governance  \
# 0      NaN             NaN               NaN               NaN
# 1      NaN             NaN               NaN               NaN
# 2      NaN             NaN               NaN               NaN
# 3      NaN             NaN               NaN               NaN
# 4      NaN             NaN               NaN               NaN
# ...    ...             ...               ...               ...
# 69784  RUS        0.624176             False          0.358850
# 69785  RUS        0.642995             False          0.365093
# 69786  RUS        0.645651             False          0.370905
# 69787  RUS        0.670757             False          0.378865
# 69788  RUS        0.682646             False          0.363537
#
#       no_value_governance  value_social  ...      fobvalue  primaryValue  \
# 0                     NaN           NaN  ...           NaN           NaN
# 1                     NaN           NaN  ...           NaN           NaN
# 2                     NaN           NaN  ...           NaN           NaN
# 3                     NaN           NaN  ...           NaN           NaN
# 4                     NaN           NaN  ...           NaN           NaN
# ...                   ...           ...  ...           ...           ...
# 69784               False      0.608937  ...  7.371230e+10  7.371230e+10
# 69785               False      0.582633  ...  9.337726e+10  9.337726e+10
# 69786               False      0.607808  ...  1.292011e+11  1.292011e+11
# 69787               False      0.599214  ...  1.222286e+11  1.222286e+11
# 69788               False      0.604826  ...  7.256429e+10  7.256429e+10
#
#       legacyEstimationFlag  isReported isAggregate  Total_netWgt_YearProduct  \
# 0                      NaN         NaN         NaN                       NaN
# 1                      NaN         NaN         NaN                       NaN
# 2                      NaN         NaN         NaN                       NaN
# 3                      NaN         NaN         NaN                       NaN
# 4                      NaN         NaN         NaN                       NaN
# ...                    ...         ...         ...                       ...
# 69784                  0.0       False        True              1.508749e+12
# 69785                  0.0       False        True              9.716810e+11
# 69786                  0.0       False        True              1.250927e+12
# 69787                  0.0       False        True              1.261201e+12
# 69788                  6.0       False        True              1.124761e+12
#
#       Share in % (exports)  Share HHI Exports  HHI_exports  cmdCode
# 0                      NaN                NaN          NaN     7616
# 1                      NaN                NaN          NaN     7616
# 2                      NaN                NaN          NaN     7616
# 3                      NaN                NaN          NaN     7616
# 4                      NaN                NaN          NaN     7616
# ...                    ...                ...          ...      ...
# 69784            16.892819         285.367322  1154.313467     2709
# 69785                  NaN                NaN   730.396645     2709
# 69786            20.829205         433.855770   978.296637     2709
# 69787            21.342775         455.514034  1290.653310     2709
# 69788            21.264102         452.162047  1156.375952     2709
#
# [69789 rows x 77 columns]

# %%
# df_hhi_production_egsehi.iloc[:10].to_csv("view_hhi_production_egsehi.csv")
# final_imports_df.iloc[100000:100000+10].to_csv("view_final_imports.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
# Let's join both DFs using reporter code, product, year
all_data_df = pd.merge(df_hhi_production_egsehi, final_imports_df, how="outer", left_on=["reporterCode", "Year", "cmdCode"], right_on=["reporterCode", "Year", "cmdCode"])
all_data_df
# Out:
#         Year  Country  Domestic Production Value (P_AC)    Product ISO3  \
# 0       1970  ALBANIA                               NaN  ALUMINIUM  NaN
# 1       1971  ALBANIA                               NaN  ALUMINIUM  NaN
# 2       1972  ALBANIA                               NaN  ALUMINIUM  NaN
# 3       1973  ALBANIA                               NaN  ALUMINIUM  NaN
# 4       1974  ALBANIA                               NaN  ALUMINIUM  NaN
# ...      ...      ...                               ...        ...  ...
# 484575  2020      NaN                               NaN        NaN  NaN
# 484576  2020      NaN                               NaN        NaN  NaN
# 484577  2020      NaN                               NaN        NaN  NaN
# 484578  2020      NaN                               NaN        NaN  NaN
# 484579  2020      NaN                               NaN        NaN  NaN
#
#         value_economic no_value_economic  value_governance  \
# 0                  NaN               NaN               NaN
# 1                  NaN               NaN               NaN
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4                  NaN               NaN               NaN
# ...                ...               ...               ...
# 484575             NaN               NaN               NaN
# 484576             NaN               NaN               NaN
# 484577             NaN               NaN               NaN
# 484578             NaN               NaN               NaN
# 484579             NaN               NaN               NaN
#
#        no_value_governance  value_social no_value_social  value_ecosystems  \
# 0                      NaN           NaN             NaN               NaN
# 1                      NaN           NaN             NaN               NaN
# 2                      NaN           NaN             NaN               NaN
# 3                      NaN           NaN             NaN               NaN
# 4                      NaN           NaN             NaN               NaN
# ...                    ...           ...             ...               ...
# 484575                 NaN           NaN             NaN               NaN
# 484576                 NaN           NaN             NaN               NaN
# 484577                 NaN           NaN             NaN               NaN
# 484578                 NaN           NaN             NaN               NaN
# 484579                 NaN           NaN             NaN               NaN
#
#        no_value_ecosystems  value_habitat no_value_habitat  \
# 0                      NaN            NaN              NaN
# 1                      NaN            NaN              NaN
# 2                      NaN            NaN              NaN
# 3                      NaN            NaN              NaN
# 4                      NaN            NaN              NaN
# ...                    ...            ...              ...
# 484575                 NaN            NaN              NaN
# 484576                 NaN            NaN              NaN
# 484577                 NaN            NaN              NaN
# 484578                 NaN            NaN              NaN
# 484579                 NaN            NaN              NaN
#
#         value_infrastructure no_value_infrastructure  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 484575                   NaN                     NaN
# 484576                   NaN                     NaN
# 484577                   NaN                     NaN
# 484578                   NaN                     NaN
# 484579                   NaN                     NaN
#
#         value_governance_isolated no_value_governance_isolated  EGSEHI  \
# 0                             NaN                          NaN     NaN
# 1                             NaN                          NaN     NaN
# 2                             NaN                          NaN     NaN
# 3                             NaN                          NaN     NaN
# 4                             NaN                          NaN     NaN
# ...                           ...                          ...     ...
# 484575                        NaN                          NaN     NaN
# 484576                        NaN                          NaN     NaN
# 484577                        NaN                          NaN     NaN
# 484578                        NaN                          NaN     NaN
# 484579                        NaN                          NaN     NaN
#
#         EGSEHI_6root  Value  reporterCode reporterDesc_x  \
# 0                NaN    NaN           8.0        ALBANIA
# 1                NaN    NaN           8.0        ALBANIA
# 2                NaN    NaN           8.0        ALBANIA
# 3                NaN    NaN           8.0        ALBANIA
# 4                NaN    NaN           8.0        ALBANIA
# ...              ...    ...           ...            ...
# 484575           NaN    NaN         894.0            NaN
# 484576           NaN    NaN         894.0            NaN
# 484577           NaN    NaN         894.0            NaN
# 484578           NaN    NaN         716.0            NaN
# 484579           NaN    NaN         716.0            NaN
#
#         Total_value_YearProduct  Share in % (production)  \
# 0                    57280000.0                      NaN
# 1                    60982000.0                      NaN
# 2                    68897000.0                      NaN
# 3                    75087000.0                      NaN
# 4                    83974000.0                      NaN
# ...                         ...                      ...
# 484575                      NaN                      NaN
# 484576                      NaN                      NaN
# 484577                      NaN                      NaN
# 484578                      NaN                      NaN
# 484579                      NaN                      NaN
#
#         Share HHI Production  HHI_production typeCode freqCode  refPeriodId  \
# 0                        NaN     1026.755380      NaN      NaN          NaN
# 1                        NaN     1132.922206      NaN      NaN          NaN
# 2                        NaN     1128.647391      NaN      NaN          NaN
# 3                        NaN     1185.642408      NaN      NaN          NaN
# 4                        NaN     1223.009237      NaN      NaN          NaN
# ...                      ...             ...      ...      ...          ...
# 484575                   NaN             NaN      NaN      NaN          NaN
# 484576                   NaN             NaN      NaN      NaN          NaN
# 484577                   NaN             NaN      NaN      NaN          NaN
# 484578                   NaN             NaN      NaN      NaN          NaN
# 484579                   NaN             NaN      NaN      NaN          NaN
#
#         refYear  refMonth reporterISO reporterDesc_y flowCode flowDesc  \
# 0           NaN       NaN         NaN            NaN      NaN      NaN
# 1           NaN       NaN         NaN            NaN      NaN      NaN
# 2           NaN       NaN         NaN            NaN      NaN      NaN
# 3           NaN       NaN         NaN            NaN      NaN      NaN
# 4           NaN       NaN         NaN            NaN      NaN      NaN
# ...         ...       ...         ...            ...      ...      ...
# 484575      NaN       NaN         NaN            NaN      NaN      NaN
# 484576      NaN       NaN         NaN            NaN      NaN      NaN
# 484577      NaN       NaN         NaN            NaN      NaN      NaN
# 484578      NaN       NaN         NaN            NaN      NaN      NaN
# 484579      NaN       NaN         NaN            NaN      NaN      NaN
#
#         partnerCode partnerISO partnerDesc  partner2Code partner2ISO  \
# 0               NaN        NaN         NaN           NaN         NaN
# 1               NaN        NaN         NaN           NaN         NaN
# 2               NaN        NaN         NaN           NaN         NaN
# 3               NaN        NaN         NaN           NaN         NaN
# 4               NaN        NaN         NaN           NaN         NaN
# ...             ...        ...         ...           ...         ...
# 484575          NaN        NaN         NaN           NaN         NaN
# 484576          NaN        NaN         NaN           NaN         NaN
# 484577          NaN        NaN         NaN           NaN         NaN
# 484578          NaN        NaN         NaN           NaN         NaN
# 484579          NaN        NaN         NaN           NaN         NaN
#
#        partner2Desc classificationCode classificationSearchCode_x  \
# 0               NaN                NaN                        NaN
# 1               NaN                NaN                        NaN
# 2               NaN                NaN                        NaN
# 3               NaN                NaN                        NaN
# 4               NaN                NaN                        NaN
# ...             ...                ...                        ...
# 484575          NaN                NaN                        NaN
# 484576          NaN                NaN                        NaN
# 484577          NaN                NaN                        NaN
# 484578          NaN                NaN                        NaN
# 484579          NaN                NaN                        NaN
#
#        isOriginalClassification cmdDesc  aggrLevel isLeaf customsCode  \
# 0                           NaN     NaN        NaN    NaN         NaN
# 1                           NaN     NaN        NaN    NaN         NaN
# 2                           NaN     NaN        NaN    NaN         NaN
# 3                           NaN     NaN        NaN    NaN         NaN
# 4                           NaN     NaN        NaN    NaN         NaN
# ...                         ...     ...        ...    ...         ...
# 484575                      NaN     NaN        NaN    NaN         NaN
# 484576                      NaN     NaN        NaN    NaN         NaN
# 484577                      NaN     NaN        NaN    NaN         NaN
# 484578                      NaN     NaN        NaN    NaN         NaN
# 484579                      NaN     NaN        NaN    NaN         NaN
#
#        customsDesc  mosCode  motCode motDesc  qtyUnitCode qtyUnitAbbr  qty  \
# 0              NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 1              NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 2              NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 3              NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 4              NaN      NaN      NaN     NaN          NaN         NaN  NaN
# ...            ...      ...      ...     ...          ...         ...  ...
# 484575         NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 484576         NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 484577         NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 484578         NaN      NaN      NaN     NaN          NaN         NaN  NaN
# 484579         NaN      NaN      NaN     NaN          NaN         NaN  NaN
#
#        isQtyEstimated  altQtyUnitCode altQtyUnitAbbr  altQty  \
# 0                 NaN             NaN            NaN     NaN
# 1                 NaN             NaN            NaN     NaN
# 2                 NaN             NaN            NaN     NaN
# 3                 NaN             NaN            NaN     NaN
# 4                 NaN             NaN            NaN     NaN
# ...               ...             ...            ...     ...
# 484575            NaN             NaN            NaN     NaN
# 484576            NaN             NaN            NaN     NaN
# 484577            NaN             NaN            NaN     NaN
# 484578            NaN             NaN            NaN     NaN
# 484579            NaN             NaN            NaN     NaN
#
#        isAltQtyEstimated  netWgt isNetWgtEstimated  grossWgt  \
# 0                    NaN     NaN               NaN       NaN
# 1                    NaN     NaN               NaN       NaN
# 2                    NaN     NaN               NaN       NaN
# 3                    NaN     NaN               NaN       NaN
# 4                    NaN     NaN               NaN       NaN
# ...                  ...     ...               ...       ...
# 484575               NaN     NaN               NaN       NaN
# 484576               NaN     NaN               NaN       NaN
# 484577               NaN     NaN               NaN       NaN
# 484578               NaN     NaN               NaN       NaN
# 484579               NaN     NaN               NaN       NaN
#
#        isGrossWgtEstimated  cifvalue  fobvalue  primaryValue  \
# 0                      NaN       NaN       NaN           NaN
# 1                      NaN       NaN       NaN           NaN
# 2                      NaN       NaN       NaN           NaN
# 3                      NaN       NaN       NaN           NaN
# 4                      NaN       NaN       NaN           NaN
# ...                    ...       ...       ...           ...
# 484575                 NaN       NaN       NaN           NaN
# 484576                 NaN       NaN       NaN           NaN
# 484577                 NaN       NaN       NaN           NaN
# 484578                 NaN       NaN       NaN           NaN
# 484579                 NaN       NaN       NaN           NaN
#
#         legacyEstimationFlag isReported isAggregate  Total_netWgt_YearProduct  \
# 0                        NaN        NaN         NaN                       NaN
# 1                        NaN        NaN         NaN                       NaN
# 2                        NaN        NaN         NaN                       NaN
# 3                        NaN        NaN         NaN                       NaN
# 4                        NaN        NaN         NaN                       NaN
# ...                      ...        ...         ...                       ...
# 484575                   NaN        NaN         NaN                       NaN
# 484576                   NaN        NaN         NaN                       NaN
# 484577                   NaN        NaN         NaN                       NaN
# 484578                   NaN        NaN         NaN                       NaN
# 484579                   NaN        NaN         NaN                       NaN
#
#         Share in % (exports)  Share HHI Exports  HHI_exports  cmdCode  \
# 0                        NaN                NaN          NaN     7616
# 1                        NaN                NaN          NaN     7616
# 2                        NaN                NaN          NaN     7616
# 3                        NaN                NaN          NaN     7616
# 4                        NaN                NaN          NaN     7616
# ...                      ...                ...          ...      ...
# 484575                   NaN                NaN          NaN   261510
# 484576                   NaN                NaN          NaN   261510
# 484577                   NaN                NaN          NaN   261510
# 484578                   NaN                NaN          NaN   261510
# 484579                   NaN                NaN          NaN   261510
#
#         partnerCode_import partnerISO_import partnerDesc_import  \
# 0                      NaN               NaN                NaN
# 1                      NaN               NaN                NaN
# 2                      NaN               NaN                NaN
# 3                      NaN               NaN                NaN
# 4                      NaN               NaN                NaN
# ...                    ...               ...                ...
# 484575                 0.0               W00              World
# 484576               380.0               ITA              Italy
# 484577               710.0               ZAF       South Africa
# 484578               710.0               ZAF       South Africa
# 484579                 0.0               W00              World
#
#        classificationSearchCode_y  qty_import  netWgt_import  \
# 0                             NaN         NaN            NaN
# 1                             NaN         NaN            NaN
# 2                             NaN         NaN            NaN
# 3                             NaN         NaN            NaN
# 4                             NaN         NaN            NaN
# ...                           ...         ...            ...
# 484575                         HS     63000.0        63000.0
# 484576                         HS     30000.0        30000.0
# 484577                         HS     33000.0        33000.0
# 484578                         HS         0.0            0.0
# 484579                         HS         0.0            0.0
#
#        qtyUnitAbbr_import  cifvalue_import  primaryValue_import  \
# 0                     NaN              NaN                  NaN
# 1                     NaN              NaN                  NaN
# 2                     NaN              NaN                  NaN
# 3                     NaN              NaN                  NaN
# 4                     NaN              NaN                  NaN
# ...                   ...              ...                  ...
# 484575                 kg        26944.376            26944.376
# 484576                 kg         9204.315             9204.315
# 484577                 kg        17740.061            17740.061
# 484578                NaN       845145.046           845145.046
# 484579                NaN       845145.046           845145.046
#
#         netWgt_total_import  cifvalue_total_import  primaryValue_total_import
# 0                       NaN                    NaN                        NaN
# 1                       NaN                    NaN                        NaN
# 2                       NaN                    NaN                        NaN
# 3                       NaN                    NaN                        NaN
# 4                       NaN                    NaN                        NaN
# ...                     ...                    ...                        ...
# 484575              63000.0              26944.376                  26944.376
# 484576              63000.0              26944.376                  26944.376
# 484577              63000.0              26944.376                  26944.376
# 484578                  0.0             845145.046                 845145.046
# 484579                  0.0             845145.046                 845145.046
#
# [484580 rows x 89 columns]

# %%
all_data_df["Geopolitical Risk Production"] = all_data_df["HHI_production"] * (all_data_df["EGSEHI_6root"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Exports"] = all_data_df["HHI_exports"] * (all_data_df["EGSEHI_6root"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Only Political Stability"] = all_data_df["HHI_exports"] * (all_data_df["value_governance_isolated"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))

all_data_df["Geopolitical Risk Production NO-ROOT"] = all_data_df["HHI_production"] * (all_data_df["EGSEHI"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Exports NO-ROOT"] = all_data_df["HHI_exports"] * (all_data_df["EGSEHI"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))

# %% [markdown]
# ### Extra CSV: Data without "World" entries (Import)

# %%
all_data_noWorld_df = all_data_df[all_data_df["partnerDesc_import"] != "World"]

# %% [markdown]
# ## Extra CSV: Dataframe that contains data in imports and exports risk value

# %%
all_data_no_nulls_df = all_data_df[(~all_data_df["Geopolitical Risk Production"].isna()) & ~all_data_df["Geopolitical Risk Exports"].isna()]
all_data_no_nulls_noWorld_df = all_data_noWorld_df[(~all_data_noWorld_df["Geopolitical Risk Production"].isna()) & ~all_data_noWorld_df["Geopolitical Risk Exports"].isna()]
all_data_no_nulls_df
# Out:
#         Year             Country  Domestic Production Value (P_AC)    Product  \
# 2292    2000           AUSTRALIA                      2.200000e+03   ANTIMONY
# 2293    2000           AUSTRALIA                      2.200000e+03   ANTIMONY
# 2294    2000           AUSTRALIA                      2.200000e+03   ANTIMONY
# 2295    2000           AUSTRALIA                      2.200000e+03   ANTIMONY
# 2297    2002           AUSTRALIA                      1.838000e+03   ANTIMONY
# ...      ...                 ...                               ...        ...
# 231503  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
# 231504  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
# 231505  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
# 231506  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
# 231507  2020  RUSSIAN FEDERATION                      5.244042e+08  PETROLEUM
#
#        ISO3  value_economic no_value_economic  value_governance  \
# 2292    AUS        0.504854             False          0.838319
# 2293    AUS        0.504854             False          0.838319
# 2294    AUS        0.504854             False          0.838319
# 2295    AUS        0.504854             False          0.838319
# 2297    AUS        0.504854             False          0.819858
# ...     ...             ...               ...               ...
# 231503  RUS        0.682646             False          0.363537
# 231504  RUS        0.682646             False          0.363537
# 231505  RUS        0.682646             False          0.363537
# 231506  RUS        0.682646             False          0.363537
# 231507  RUS        0.682646             False          0.363537
#
#        no_value_governance  value_social no_value_social  value_ecosystems  \
# 2292                 False      0.498050           False          0.382859
# 2293                 False      0.498050           False          0.382859
# 2294                 False      0.498050           False          0.382859
# 2295                 False      0.498050           False          0.382859
# 2297                 False      0.539942           False          0.378758
# ...                    ...           ...             ...               ...
# 231503               False      0.604826           False          0.415002
# 231504               False      0.604826           False          0.415002
# 231505               False      0.604826           False          0.415002
# 231506               False      0.604826           False          0.415002
# 231507               False      0.604826           False          0.415002
#
#        no_value_ecosystems  value_habitat no_value_habitat  \
# 2292                 False       0.499155            False
# 2293                 False       0.499155            False
# 2294                 False       0.499155            False
# 2295                 False       0.499155            False
# 2297                 False       0.496554            False
# ...                    ...            ...              ...
# 231503               False       0.515080            False
# 231504               False       0.515080            False
# 231505               False       0.515080            False
# 231506               False       0.515080            False
# 231507               False       0.515080            False
#
#         value_infrastructure no_value_infrastructure  \
# 2292                0.200596                   False
# 2293                0.200596                   False
# 2294                0.200596                   False
# 2295                0.200596                   False
# 2297                0.191853                   False
# ...                      ...                     ...
# 231503              0.158387                   False
# 231504              0.158387                   False
# 231505              0.158387                   False
# 231506              0.158387                   False
# 231507              0.158387                   False
#
#         value_governance_isolated no_value_governance_isolated    EGSEHI  \
# 2292                     0.799577                        False  0.008081
# 2293                     0.799577                        False  0.008081
# 2294                     0.799577                        False  0.008081
# 2295                     0.799577                        False  0.008081
# 2297                     0.775219                        False  0.008064
# ...                           ...                          ...       ...
# 231503                   0.444282                        False  0.005082
# 231504                   0.444282                        False  0.005082
# 231505                   0.444282                        False  0.005082
# 231506                   0.444282                        False  0.005082
# 231507                   0.444282                        False  0.005082
#
#         EGSEHI_6root         Value  reporterCode      reporterDesc_x  \
# 2292    2.783947e-13  2.200000e+03          36.0           AUSTRALIA
# 2293    2.783947e-13  2.200000e+03          36.0           AUSTRALIA
# 2294    2.783947e-13  2.200000e+03          36.0           AUSTRALIA
# 2295    2.783947e-13  2.200000e+03          36.0           AUSTRALIA
# 2297    2.749735e-13  1.838000e+03          36.0           AUSTRALIA
# ...              ...           ...           ...                 ...
# 231503  1.722358e-14  5.244042e+08         643.0  RUSSIAN FEDERATION
# 231504  1.722358e-14  5.244042e+08         643.0  RUSSIAN FEDERATION
# 231505  1.722358e-14  5.244042e+08         643.0  RUSSIAN FEDERATION
# 231506  1.722358e-14  5.244042e+08         643.0  RUSSIAN FEDERATION
# 231507  1.722358e-14  5.244042e+08         643.0  RUSSIAN FEDERATION
#
#         Total_value_YearProduct  Share in % (production)  \
# 2292               1.175320e+05                 1.871831
# 2293               1.175320e+05                 1.871831
# 2294               1.175320e+05                 1.871831
# 2295               1.175320e+05                 1.871831
# 2297               1.426690e+05                 1.288297
# ...                         ...                      ...
# 231503             4.104270e+09                12.777041
# 231504             4.104270e+09                12.777041
# 231505             4.104270e+09                12.777041
# 231506             4.104270e+09                12.777041
# 231507             4.104270e+09                12.777041
#
#         Share HHI Production  HHI_production typeCode freqCode  refPeriodId  \
# 2292                3.503750     7181.517035        C        A   20000101.0
# 2293                3.503750     7181.517035        C        A   20000101.0
# 2294                3.503750     7181.517035        C        A   20000101.0
# 2295                3.503750     7181.517035        C        A   20000101.0
# 2297                1.659708     7295.634830        C        A   20020101.0
# ...                      ...             ...      ...      ...          ...
# 231503            163.252777      799.455587        C        A   20200101.0
# 231504            163.252777      799.455587        C        A   20200101.0
# 231505            163.252777      799.455587        C        A   20200101.0
# 231506            163.252777      799.455587        C        A   20200101.0
# 231507            163.252777      799.455587        C        A   20200101.0
#
#         refYear  refMonth reporterISO      reporterDesc_y flowCode flowDesc  \
# 2292     2000.0      52.0         AUS           Australia        X   Export
# 2293     2000.0      52.0         AUS           Australia        X   Export
# 2294     2000.0      52.0         AUS           Australia        X   Export
# 2295     2000.0      52.0         AUS           Australia        X   Export
# 2297     2002.0      52.0         AUS           Australia        X   Export
# ...         ...       ...         ...                 ...      ...      ...
# 231503   2020.0      52.0         RUS  Russian Federation        X   Export
# 231504   2020.0      52.0         RUS  Russian Federation        X   Export
# 231505   2020.0      52.0         RUS  Russian Federation        X   Export
# 231506   2020.0      52.0         RUS  Russian Federation        X   Export
# 231507   2020.0      52.0         RUS  Russian Federation        X   Export
#
#         partnerCode partnerISO partnerDesc  partner2Code partner2ISO  \
# 2292            0.0        W00       World           0.0         W00
# 2293            0.0        W00       World           0.0         W00
# 2294            0.0        W00       World           0.0         W00
# 2295            0.0        W00       World           0.0         W00
# 2297            0.0        W00       World           0.0         W00
# ...             ...        ...         ...           ...         ...
# 231503          0.0        W00       World           0.0         W00
# 231504          0.0        W00       World           0.0         W00
# 231505          0.0        W00       World           0.0         W00
# 231506          0.0        W00       World           0.0         W00
# 231507          0.0        W00       World           0.0         W00
#
#        partner2Desc classificationCode classificationSearchCode_x  \
# 2292          World                 H1                         HS
# 2293          World                 H1                         HS
# 2294          World                 H1                         HS
# 2295          World                 H1                         HS
# 2297          World                 H2                         HS
# ...             ...                ...                        ...
# 231503        World                 H5                         HS
# 231504        World                 H5                         HS
# 231505        World                 H5                         HS
# 231506        World                 H5                         HS
# 231507        World                 H5                         HS
#
#        isOriginalClassification  \
# 2292                       True
# 2293                       True
# 2294                       True
# 2295                       True
# 2297                       True
# ...                         ...
# 231503                     True
# 231504                     True
# 231505                     True
# 231506                     True
# 231507                     True
#
#                                                   cmdDesc  aggrLevel isLeaf  \
# 2292                       Antimony ores and concentrates        6.0   True
# 2293                       Antimony ores and concentrates        6.0   True
# 2294                       Antimony ores and concentrates        6.0   True
# 2295                       Antimony ores and concentrates        6.0   True
# 2297                       Antimony ores and concentrates        6.0   True
# ...                                                   ...        ...    ...
# 231503  Petroleum oils and oils obtained from bitumino...        4.0  False
# 231504  Petroleum oils and oils obtained from bitumino...        4.0  False
# 231505  Petroleum oils and oils obtained from bitumino...        4.0  False
# 231506  Petroleum oils and oils obtained from bitumino...        4.0  False
# 231507  Petroleum oils and oils obtained from bitumino...        4.0  False
#
#        customsCode customsDesc  mosCode  motCode    motDesc  qtyUnitCode  \
# 2292           C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 2293           C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 2294           C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 2295           C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 2297           C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# ...            ...         ...      ...      ...        ...          ...
# 231503         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 231504         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 231505         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 231506         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 231507         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
#
#        qtyUnitAbbr           qty isQtyEstimated  altQtyUnitCode  \
# 2292            kg  2.356867e+06          False            -1.0
# 2293            kg  2.356867e+06          False            -1.0
# 2294            kg  2.356867e+06          False            -1.0
# 2295            kg  2.356867e+06          False            -1.0
# 2297            kg  1.780000e+06          False            -1.0
# ...            ...           ...            ...             ...
# 231503          kg  2.391704e+11           True            -1.0
# 231504          kg  2.391704e+11           True            -1.0
# 231505          kg  2.391704e+11           True            -1.0
# 231506          kg  2.391704e+11           True            -1.0
# 231507          kg  2.391704e+11           True            -1.0
#
#        altQtyUnitAbbr  altQty isAltQtyEstimated        netWgt  \
# 2292              NaN     NaN             False  2.356867e+06
# 2293              NaN     NaN             False  2.356867e+06
# 2294              NaN     NaN             False  2.356867e+06
# 2295              NaN     NaN             False  2.356867e+06
# 2297              NaN     NaN             False  1.780000e+06
# ...               ...     ...               ...           ...
# 231503            NaN     0.0             False  2.391704e+11
# 231504            NaN     0.0             False  2.391704e+11
# 231505            NaN     0.0             False  2.391704e+11
# 231506            NaN     0.0             False  2.391704e+11
# 231507            NaN     0.0             False  2.391704e+11
#
#        isNetWgtEstimated  grossWgt isGrossWgtEstimated  cifvalue  \
# 2292               False       NaN               False       NaN
# 2293               False       NaN               False       NaN
# 2294               False       NaN               False       NaN
# 2295               False       NaN               False       NaN
# 2297               False       NaN               False       NaN
# ...                  ...       ...                 ...       ...
# 231503              True       0.0               False       0.0
# 231504              True       0.0               False       0.0
# 231505              True       0.0               False       0.0
# 231506              True       0.0               False       0.0
# 231507              True       0.0               False       0.0
#
#             fobvalue  primaryValue  legacyEstimationFlag isReported  \
# 2292    1.624825e+06  1.624825e+06                   0.0      False
# 2293    1.624825e+06  1.624825e+06                   0.0      False
# 2294    1.624825e+06  1.624825e+06                   0.0      False
# 2295    1.624825e+06  1.624825e+06                   0.0      False
# 2297    1.390594e+06  1.390594e+06                   0.0       True
# ...              ...           ...                   ...        ...
# 231503  7.256429e+10  7.256429e+10                   6.0      False
# 231504  7.256429e+10  7.256429e+10                   6.0      False
# 231505  7.256429e+10  7.256429e+10                   6.0      False
# 231506  7.256429e+10  7.256429e+10                   6.0      False
# 231507  7.256429e+10  7.256429e+10                   6.0      False
#
#        isAggregate  Total_netWgt_YearProduct  Share in % (exports)  \
# 2292         False              6.013568e+06             39.192489
# 2293         False              6.013568e+06             39.192489
# 2294         False              6.013568e+06             39.192489
# 2295         False              6.013568e+06             39.192489
# 2297         False              8.040744e+07              2.213725
# ...            ...                       ...                   ...
# 231503        True              1.124761e+12             21.264102
# 231504        True              1.124761e+12             21.264102
# 231505        True              1.124761e+12             21.264102
# 231506        True              1.124761e+12             21.264102
# 231507        True              1.124761e+12             21.264102
#
#         Share HHI Exports  HHI_exports  cmdCode  partnerCode_import  \
# 2292          1536.051224  2430.155539   261710               842.0
# 2293          1536.051224  2430.155539   261710               360.0
# 2294          1536.051224  2430.155539   261710               710.0
# 2295          1536.051224  2430.155539   261710                 0.0
# 2297             4.900580  5416.885735   261710               710.0
# ...                   ...          ...      ...                 ...
# 231503         452.162047  1156.375952     2709                31.0
# 231504         452.162047  1156.375952     2709               398.0
# 231505         452.162047  1156.375952     2709               417.0
# 231506         452.162047  1156.375952     2709               579.0
# 231507         452.162047  1156.375952     2709               842.0
#
#        partnerISO_import partnerDesc_import classificationSearchCode_y  \
# 2292                 USA                USA                         HS
# 2293                 IDN          Indonesia                         HS
# 2294                 ZAF       South Africa                         HS
# 2295                 W00              World                         HS
# 2297                 ZAF       South Africa                         HS
# ...                  ...                ...                        ...
# 231503               AZE         Azerbaijan                         HS
# 231504               KAZ         Kazakhstan                         HS
# 231505               KGZ         Kyrgyzstan                         HS
# 231506               NOR             Norway                         HS
# 231507               USA                USA                         HS
#
#          qty_import  netWgt_import qtyUnitAbbr_import  cifvalue_import  \
# 2292       1080.000       1080.000                 kg          2090.00
# 2293         56.000         56.000                 kg         12691.00
# 2294       1000.000       1000.000                 kg          1756.00
# 2295       2136.000       2136.000                 kg         16538.00
# 2297       1015.000       1015.000                 kg          1937.00
# ...             ...            ...                ...              ...
# 231503        7.000          7.000                 kg           190.00
# 231504  2532328.995    2532328.995                 kg        570968.64
# 231505   230734.000     230734.000                 kg         55663.00
# 231506        5.000          5.000                 kg            18.87
# 231507        0.000          0.000                NaN          1600.42
#
#         primaryValue_import  netWgt_total_import  cifvalue_total_import  \
# 2292                2090.00               2136.0               16538.00
# 2293               12691.00               2136.0               16538.00
# 2294                1756.00               2136.0               16538.00
# 2295               16538.00               2136.0               16538.00
# 2297                1937.00               2030.0                3675.00
# ...                     ...                  ...                    ...
# 231503               190.00                  0.0              628440.93
# 231504            570968.64                  0.0              628440.93
# 231505             55663.00                  0.0              628440.93
# 231506                18.87                  0.0              628440.93
# 231507              1600.42                  0.0              628440.93
#
#         primaryValue_total_import  Geopolitical Risk Production  \
# 2292                     16538.00                  1.804358e-11
# 2293                     16538.00                  9.355933e-13
# 2294                     16538.00                  1.670702e-11
# 2295                     16538.00                  3.568620e-11
# 2297                      3675.00                  1.407196e-11
# ...                           ...                           ...
# 231503                  628440.93                  2.348443e-20
# 231504                  628440.93                  8.495756e-15
# 231505                  628440.93                  7.740937e-16
# 231506                  628440.93                  1.677459e-20
# 231507                  628440.93                  0.000000e+00
#
#         Geopolitical Risk Exports  Geopolitical Risk Only Political Stability  \
# 2292                 6.105774e-12                                1.753638e+01
# 2293                 3.165957e-13                                9.092940e-01
# 2294                 5.653494e-12                                1.623739e+01
# 2295                 1.207586e-11                                3.468307e+01
# 2297                 1.044819e-11                                2.945604e+01
# ...                           ...                                         ...
# 231503               3.396915e-20                                8.762337e-07
# 231504               1.228872e-14                                3.169874e-01
# 231505               1.119691e-15                                2.888242e-02
# 231506               2.426368e-20                                6.258812e-07
# 231507               0.000000e+00                                0.000000e+00
#
#         Geopolitical Risk Production NO-ROOT  \
# 2292                            5.237275e-01
# 2293                            2.715624e-02
# 2294                            4.849329e-01
# 2295                            1.035817e+00
# 2297                            4.126787e-01
# ...                                      ...
# 231503                          6.929104e-09
# 231504                          2.506682e-03
# 231505                          2.283971e-04
# 231506                          4.949360e-09
# 231507                          0.000000e+00
#
#         Geopolitical Risk Exports NO-ROOT
# 2292                         1.772243e-01
# 2293                         9.189408e-03
# 2294                         1.640966e-01
# 2295                         3.505103e-01
# 2297                         3.064070e-01
# ...                                   ...
# 231503                       1.002263e-08
# 231504                       3.625800e-03
# 231505                       3.303660e-04
# 231506                       7.159023e-09
# 231507                       0.000000e+00
#
# [129028 rows x 94 columns]

# %% [markdown]
# ## Save results

# %%
all_data_df.to_csv("../data/all_consolidated_data/all_consolidated_data.csv", index=False)
all_data_noWorld_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noWorld.csv", index=False)

# %%
all_data_no_nulls_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noNulls.csv", index=True)
all_data_no_nulls_noWorld_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noNulls_noWorld.csv", index=True)
