# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Join conformed table with imports table

# %%
df_hhi_production_egsehi = pd.read_csv("../data/hhi_production_exports_egsehi_conformed_table.csv")
final_imports_df = pd.read_csv("../data/imports_consolidated/imports_consolidated.csv")
# Out:
# c:\Users\zacat\OneDrive\Documentos\Investigacion\investigacion-gnn-cic\rb_venv3715\lib\site-packages\IPython\core\interactiveshell.py:3553: DtypeWarning: Columns (11,13,15,17,19,21,23,33,34,38,39,40,41,43,44,46,47,48,49,50,51,53,54,55,58,61,63,65,67,69,74,75,76) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Lets select "important" columns
# columns = [
#     "period", "reporterCode", "reporterISO", "reporterDesc", "flowDesc",
#     "partnerCode", "partnerISO", "partnerDesc", "classificationSearchCode",
#     "cmdCode", "cmdDesc", "qty", "netWgt", 
#     "qtyUnitAbbr", "cifvalue", "primaryValue"
# ]
columns = [
    "period", "reporterCode",
    "partnerCode", "partnerISO", "partnerDesc",
    "cmdCode", "qty", "netWgt", 
    "qtyUnitAbbr", "cifvalue", "primaryValue", 
    "netWgt_total_import", "cifvalue_total_import", "primaryValue_total_import"
]
final_imports_df = final_imports_df[columns]
final_imports_df.rename(
    columns={
        "period": "Year",
        "partnerCode": "partnerCode_import",
        "partnerISO": "partnerISO_import",
        "partnerDesc": "partnerDesc_import",
        "qty": "qty_import",
        "netWgt": "netWgt_import",
        "qtyUnitAbbr": "qtyUnitAbbr_import",
        "cifvalue": "cifvalue_import",
        "primaryValue": "primaryValue_import"
    }, inplace=True)

final_imports_df
# Out:
#         Year  reporterCode  partnerCode_import partnerISO_import  \
# 0       2000            12                 528               NLD
# 1       2000            12                 156               CHN
# 2       2000            12                   0               W00
# 3       2000            12                 724               ESP
# 4       2000            20                 724               ESP
# ...      ...           ...                 ...               ...
# 405796  2020           894                   0               W00
# 405797  2020           894                 380               ITA
# 405798  2020           894                 710               ZAF
# 405799  2020           716                 710               ZAF
# 405800  2020           716                   0               W00
#
#        partnerDesc_import  cmdCode  qty_import  netWgt_import  \
# 0             Netherlands     2606    100400.0       100400.0
# 1                   China     2606    263140.0       263140.0
# 2                   World     2606    364790.0       364790.0
# 3                   Spain     2606      1250.0         1250.0
# 4                   Spain     2606        42.0           42.0
# ...                   ...      ...         ...            ...
# 405796              World   261510     63000.0        63000.0
# 405797              Italy   261510     30000.0        30000.0
# 405798       South Africa   261510     33000.0        33000.0
# 405799       South Africa   261510         0.0            0.0
# 405800              World   261510         0.0            0.0
#
#        qtyUnitAbbr_import  cifvalue_import  primaryValue_import  \
# 0                      kg        37768.000            37768.000
# 1                      kg        74064.000            74064.000
# 2                      kg       112483.000           112483.000
# 3                      kg          651.000              651.000
# 4                      kg           50.000               50.000
# ...                   ...              ...                  ...
# 405796                 kg        26944.376            26944.376
# 405797                 kg         9204.315             9204.315
# 405798                 kg        17740.061            17740.061
# 405799                NaN       845145.046           845145.046
# 405800                NaN       845145.046           845145.046
#
#         netWgt_total_import  cifvalue_total_import  primaryValue_total_import
# 0                  364790.0             112483.000                 112483.000
# 1                  364790.0             112483.000                 112483.000
# 2                  364790.0             112483.000                 112483.000
# 3                  364790.0             112483.000                 112483.000
# 4                      42.0                 50.000                     50.000
# ...                     ...                    ...                        ...
# 405796              63000.0              26944.376                  26944.376
# 405797              63000.0              26944.376                  26944.376
# 405798              63000.0              26944.376                  26944.376
# 405799                  0.0             845145.046                 845145.046
# 405800                  0.0             845145.046                 845145.046
#
# [405801 rows x 14 columns]

# %%
df_hhi_production_egsehi
# Out:
#               Country               Product   cmdCode Source  Year  \
# 0             ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1             ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2           ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3           AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4             AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...               ...                   ...       ...    ...   ...
# 474620          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 474621        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 474622  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 474623     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 474624     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#         Domestic Production Value (P_AC)  Value (Ton) qtyUnitAbbr  \
# 0                           4.395020e+08     439502.0          kg
# 1                           2.000000e+09    2000000.0          kg
# 2                           3.455760e+08     345576.0          kg
# 3                           5.688500e+10   56885000.0          kg
# 4                           1.137872e+09    1137872.0          kg
# ...                                  ...          ...         ...
# 474620                               NaN          NaN          kg
# 474621                      8.770000e+05        877.0          kg
# 474622                      7.000000e+03          7.0          kg
# 474623                      4.127000e+06       4127.0          kg
# 474624                               NaN          NaN          kg
#
#         reporterCode ISO3  value_economic no_value_economic  value_governance  \
# 0                8.0  NaN             NaN               NaN               NaN
# 1               12.0  NaN             NaN               NaN               NaN
# 2               32.0  NaN             NaN               NaN               NaN
# 3               36.0  NaN             NaN               NaN               NaN
# 4               40.0  NaN             NaN               NaN               NaN
# ...              ...  ...             ...               ...               ...
# 474620         724.0  ESP        0.498795             False          0.646452
# 474621         804.0  UKR        0.421433             False          0.363488
# 474622         842.0  USA        0.613565             False          0.693259
# 474623         860.0  UZB        0.526698             False          0.328749
# 474624         890.0  NaN             NaN               NaN               NaN
#
#        no_value_governance  value_social no_value_social  value_ecosystems  \
# 0                      NaN           NaN             NaN               NaN
# 1                      NaN           NaN             NaN               NaN
# 2                      NaN           NaN             NaN               NaN
# 3                      NaN           NaN             NaN               NaN
# 4                      NaN           NaN             NaN               NaN
# ...                    ...           ...             ...               ...
# 474620               False      0.462754           False          0.281208
# 474621               False      0.496721           False          0.426281
# 474622               False      0.653018           False          0.424584
# 474623               False      0.302127           False          0.506797
# 474624                 NaN           NaN             NaN               NaN
#
#        no_value_ecosystems  value_habitat no_value_habitat  \
# 0                      NaN            NaN              NaN
# 1                      NaN            NaN              NaN
# 2                      NaN            NaN              NaN
# 3                      NaN            NaN              NaN
# 4                      NaN            NaN              NaN
# ...                    ...            ...              ...
# 474620               False       0.373402            False
# 474621               False       0.469000            False
# 474622               False       0.453989            False
# 474623               False       0.422226            False
# 474624                 NaN            NaN              NaN
#
#         value_infrastructure no_value_infrastructure  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 474620              0.335442                   False
# 474621              0.292860                   False
# 474622              0.275346                   False
# 474623              0.267437                   False
# 474624                   NaN                     NaN
#
#         value_governance_isolated no_value_governance_isolated    EGSEHI  \
# 0                             NaN                          NaN       NaN
# 1                             NaN                          NaN       NaN
# 2                             NaN                          NaN       NaN
# 3                             NaN                          NaN       NaN
# 4                             NaN                          NaN       NaN
# ...                           ...                          ...       ...
# 474620                   0.638047                        False  0.005256
# 474621                   0.369888                        False  0.004455
# 474622                   0.566284                        False  0.014742
# 474623                   0.494995                        False  0.002994
# 474624                        NaN                          NaN       NaN
#
#         EGSEHI_6root             Product_x      Value  \
# 0                NaN                   NaN        NaN
# 1                NaN                   NaN        NaN
# 2                NaN                   NaN        NaN
# 3                NaN                   NaN        NaN
# 4                NaN                   NaN        NaN
# ...              ...                   ...        ...
# 474620  2.107548e-14  URANIUM (U3O8-CONT.)        NaN
# 474621  7.819201e-15  URANIUM (U3O8-CONT.)   877000.0
# 474622  1.026623e-11  URANIUM (U3O8-CONT.)     7000.0
# 474623  7.199459e-16  URANIUM (U3O8-CONT.)  4127000.0
# 474624           NaN  URANIUM (U3O8-CONT.)        NaN
#
#         Total_value_YearProduct  Share in % (production)  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 474620               56269000.0                      NaN
# 474621               56269000.0                 1.558585
# 474622               56269000.0                 0.012440
# 474623               56269000.0                 7.334411
# 474624               56269000.0                      NaN
#
#         Share HHI Production  HHI_production  HHI_production_scaled typeCode  \
# 0                        NaN             NaN                    NaN      NaN
# 1                        NaN             NaN                    NaN      NaN
# 2                        NaN             NaN                    NaN      NaN
# 3                        NaN             NaN                    NaN      NaN
# 4                        NaN             NaN                    NaN      NaN
# ...                      ...             ...                    ...      ...
# 474620                   NaN     2182.434818               0.182702      NaN
# 474621              2.429186     2182.434818               0.182702        C
# 474622              0.000155     2182.434818               0.182702      NaN
# 474623             53.793592     2182.434818               0.182702      NaN
# 474624                   NaN     2182.434818               0.182702      NaN
#
#        freqCode  refPeriodId  refYear  refMonth reporterISO reporterDesc  \
# 0           NaN          NaN      NaN       NaN         NaN          NaN
# 1           NaN          NaN      NaN       NaN         NaN          NaN
# 2           NaN          NaN      NaN       NaN         NaN          NaN
# 3           NaN          NaN      NaN       NaN         NaN          NaN
# 4           NaN          NaN      NaN       NaN         NaN          NaN
# ...         ...          ...      ...       ...         ...          ...
# 474620      NaN          NaN      NaN       NaN         NaN          NaN
# 474621        A   20200101.0   2020.0      52.0         UKR      Ukraine
# 474622      NaN          NaN      NaN       NaN         NaN          NaN
# 474623      NaN          NaN      NaN       NaN         NaN          NaN
# 474624      NaN          NaN      NaN       NaN         NaN          NaN
#
#        flowCode flowDesc  partnerCode partnerISO partnerDesc  partner2Code  \
# 0           NaN      NaN          NaN        NaN         NaN           NaN
# 1           NaN      NaN          NaN        NaN         NaN           NaN
# 2           NaN      NaN          NaN        NaN         NaN           NaN
# 3           NaN      NaN          NaN        NaN         NaN           NaN
# 4           NaN      NaN          NaN        NaN         NaN           NaN
# ...         ...      ...          ...        ...         ...           ...
# 474620      NaN      NaN          NaN        NaN         NaN           NaN
# 474621        X   Export          0.0        W00       World           0.0
# 474622      NaN      NaN          NaN        NaN         NaN           NaN
# 474623      NaN      NaN          NaN        NaN         NaN           NaN
# 474624      NaN      NaN          NaN        NaN         NaN           NaN
#
#        partner2ISO partner2Desc classificationCode classificationSearchCode  \
# 0              NaN          NaN                NaN                      NaN
# 1              NaN          NaN                NaN                      NaN
# 2              NaN          NaN                NaN                      NaN
# 3              NaN          NaN                NaN                      NaN
# 4              NaN          NaN                NaN                      NaN
# ...            ...          ...                ...                      ...
# 474620         NaN          NaN                NaN                      NaN
# 474621         W00        World                 H5                       HS
# 474622         NaN          NaN                NaN                      NaN
# 474623         NaN          NaN                NaN                      NaN
# 474624         NaN          NaN                NaN                      NaN
#
#        isOriginalClassification                        cmdDesc  aggrLevel  \
# 0                           NaN                            NaN        NaN
# 1                           NaN                            NaN        NaN
# 2                           NaN                            NaN        NaN
# 3                           NaN                            NaN        NaN
# 4                           NaN                            NaN        NaN
# ...                         ...                            ...        ...
# 474620                      NaN                            NaN        NaN
# 474621                     True  Uranium ores and concentrates        6.0
# 474622                      NaN                            NaN        NaN
# 474623                      NaN                            NaN        NaN
# 474624                      NaN                            NaN        NaN
#
#        isLeaf customsCode customsDesc  mosCode  motCode    motDesc  \
# 0         NaN         NaN         NaN      NaN      NaN        NaN
# 1         NaN         NaN         NaN      NaN      NaN        NaN
# 2         NaN         NaN         NaN      NaN      NaN        NaN
# 3         NaN         NaN         NaN      NaN      NaN        NaN
# 4         NaN         NaN         NaN      NaN      NaN        NaN
# ...       ...         ...         ...      ...      ...        ...
# 474620    NaN         NaN         NaN      NaN      NaN        NaN
# 474621   True         C00   TOTAL CPC      0.0      0.0  TOTAL MOT
# 474622    NaN         NaN         NaN      NaN      NaN        NaN
# 474623    NaN         NaN         NaN      NaN      NaN        NaN
# 474624    NaN         NaN         NaN      NaN      NaN        NaN
#
#         qtyUnitCode  qty isQtyEstimated  altQtyUnitCode altQtyUnitAbbr  \
# 0               NaN  NaN            NaN             NaN            NaN
# 1               NaN  NaN            NaN             NaN            NaN
# 2               NaN  NaN            NaN             NaN            NaN
# 3               NaN  NaN            NaN             NaN            NaN
# 4               NaN  NaN            NaN             NaN            NaN
# ...             ...  ...            ...             ...            ...
# 474620          NaN  NaN            NaN             NaN            NaN
# 474621          8.0  0.2          False             8.0             kg
# 474622          NaN  NaN            NaN             NaN            NaN
# 474623          NaN  NaN            NaN             NaN            NaN
# 474624          NaN  NaN            NaN             NaN            NaN
#
#         altQty isAltQtyEstimated  netWgt isNetWgtEstimated  grossWgt  \
# 0          NaN               NaN     NaN               NaN       NaN
# 1          NaN               NaN     NaN               NaN       NaN
# 2          NaN               NaN     NaN               NaN       NaN
# 3          NaN               NaN     NaN               NaN       NaN
# 4          NaN               NaN     NaN               NaN       NaN
# ...        ...               ...     ...               ...       ...
# 474620     NaN               NaN     NaN               NaN       NaN
# 474621     0.2             False     0.2             False       0.0
# 474622     NaN               NaN     NaN               NaN       NaN
# 474623     NaN               NaN     NaN               NaN       NaN
# 474624     NaN               NaN     NaN               NaN       NaN
#
#        isGrossWgtEstimated  cifvalue  fobvalue  primaryValue  \
# 0                      NaN       NaN       NaN           NaN
# 1                      NaN       NaN       NaN           NaN
# 2                      NaN       NaN       NaN           NaN
# 3                      NaN       NaN       NaN           NaN
# 4                      NaN       NaN       NaN           NaN
# ...                    ...       ...       ...           ...
# 474620                 NaN       NaN       NaN           NaN
# 474621               False       0.0     23.29         23.29
# 474622                 NaN       NaN       NaN           NaN
# 474623                 NaN       NaN       NaN           NaN
# 474624                 NaN       NaN       NaN           NaN
#
#         legacyEstimationFlag isReported isAggregate Product_y  \
# 0                        NaN        NaN         NaN       NaN
# 1                        NaN        NaN         NaN       NaN
# 2                        NaN        NaN         NaN       NaN
# 3                        NaN        NaN         NaN       NaN
# 4                        NaN        NaN         NaN       NaN
# ...                      ...        ...         ...       ...
# 474620                   NaN        NaN         NaN       NaN
# 474621                   0.0      False        True   URANIUM
# 474622                   NaN        NaN         NaN       NaN
# 474623                   NaN        NaN         NaN       NaN
# 474624                   NaN        NaN         NaN       NaN
#
#         Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 0                            NaN                   NaN                NaN
# 1                            NaN                   NaN                NaN
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                            NaN                   NaN                NaN
# ...                          ...                   ...                ...
# 474620                       NaN                   NaN                NaN
# 474621                 6182528.2              0.000003       1.046472e-11
# 474622                       NaN                   NaN                NaN
# 474623                       NaN                   NaN                NaN
# 474624                       NaN                   NaN                NaN
#
#         HHI_exports  HHI_exports_scaled
# 0               NaN                 NaN
# 1               NaN                 NaN
# 2               NaN                 NaN
# 3               NaN                 NaN
# 4               NaN                 NaN
# ...             ...                 ...
# 474620          NaN                 NaN
# 474621  5782.582977            0.557482
# 474622          NaN                 NaN
# 474623          NaN                 NaN
# 474624          NaN                 NaN
#
# [474625 rows x 82 columns]

# %%
# df_hhi_production_egsehi.iloc[:10].to_csv("view_hhi_production_egsehi.csv")
# final_imports_df.iloc[100000:100000+10].to_csv("view_final_imports.csv")

# %%
# Let's join both DFs using reporter code, product, year
all_data_df = pd.merge(df_hhi_production_egsehi, final_imports_df, how="outer", left_on=["reporterCode", "Year", "cmdCode"], right_on=["reporterCode", "Year", "cmdCode"])
all_data_df
# Out:
#           Country              Product   cmdCode Source  Year  \
# 0         ALBANIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 1         ALGERIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 2       ARGENTINA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 3       AUSTRALIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 4         AUSTRIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# ...           ...                  ...       ...    ...   ...
# 862919        NaN                  NaN  261510.0    NaN  2020
# 862920        NaN                  NaN  261510.0    NaN  2020
# 862921        NaN                  NaN  261510.0    NaN  2020
# 862922        NaN                  NaN  261510.0    NaN  2020
# 862923        NaN                  NaN  261510.0    NaN  2020
#
#         Domestic Production Value (P_AC)  Value (Ton) qtyUnitAbbr  \
# 0                           4.395020e+08     439502.0          kg
# 1                           2.000000e+09    2000000.0          kg
# 2                           3.455760e+08     345576.0          kg
# 3                           5.688500e+10   56885000.0          kg
# 4                           1.137872e+09    1137872.0          kg
# ...                                  ...          ...         ...
# 862919                               NaN          NaN         NaN
# 862920                               NaN          NaN         NaN
# 862921                               NaN          NaN         NaN
# 862922                               NaN          NaN         NaN
# 862923                               NaN          NaN         NaN
#
#         reporterCode ISO3  value_economic no_value_economic  value_governance  \
# 0                8.0  NaN             NaN               NaN               NaN
# 1               12.0  NaN             NaN               NaN               NaN
# 2               32.0  NaN             NaN               NaN               NaN
# 3               36.0  NaN             NaN               NaN               NaN
# 4               40.0  NaN             NaN               NaN               NaN
# ...              ...  ...             ...               ...               ...
# 862919         894.0  NaN             NaN               NaN               NaN
# 862920         894.0  NaN             NaN               NaN               NaN
# 862921         894.0  NaN             NaN               NaN               NaN
# 862922         716.0  NaN             NaN               NaN               NaN
# 862923         716.0  NaN             NaN               NaN               NaN
#
#        no_value_governance  value_social no_value_social  value_ecosystems  \
# 0                      NaN           NaN             NaN               NaN
# 1                      NaN           NaN             NaN               NaN
# 2                      NaN           NaN             NaN               NaN
# 3                      NaN           NaN             NaN               NaN
# 4                      NaN           NaN             NaN               NaN
# ...                    ...           ...             ...               ...
# 862919                 NaN           NaN             NaN               NaN
# 862920                 NaN           NaN             NaN               NaN
# 862921                 NaN           NaN             NaN               NaN
# 862922                 NaN           NaN             NaN               NaN
# 862923                 NaN           NaN             NaN               NaN
#
#        no_value_ecosystems  value_habitat no_value_habitat  \
# 0                      NaN            NaN              NaN
# 1                      NaN            NaN              NaN
# 2                      NaN            NaN              NaN
# 3                      NaN            NaN              NaN
# 4                      NaN            NaN              NaN
# ...                    ...            ...              ...
# 862919                 NaN            NaN              NaN
# 862920                 NaN            NaN              NaN
# 862921                 NaN            NaN              NaN
# 862922                 NaN            NaN              NaN
# 862923                 NaN            NaN              NaN
#
#         value_infrastructure no_value_infrastructure  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 862919                   NaN                     NaN
# 862920                   NaN                     NaN
# 862921                   NaN                     NaN
# 862922                   NaN                     NaN
# 862923                   NaN                     NaN
#
#         value_governance_isolated no_value_governance_isolated  EGSEHI  \
# 0                             NaN                          NaN     NaN
# 1                             NaN                          NaN     NaN
# 2                             NaN                          NaN     NaN
# 3                             NaN                          NaN     NaN
# 4                             NaN                          NaN     NaN
# ...                           ...                          ...     ...
# 862919                        NaN                          NaN     NaN
# 862920                        NaN                          NaN     NaN
# 862921                        NaN                          NaN     NaN
# 862922                        NaN                          NaN     NaN
# 862923                        NaN                          NaN     NaN
#
#         EGSEHI_6root Product_x  Value  Total_value_YearProduct  \
# 0                NaN       NaN    NaN                      NaN
# 1                NaN       NaN    NaN                      NaN
# 2                NaN       NaN    NaN                      NaN
# 3                NaN       NaN    NaN                      NaN
# 4                NaN       NaN    NaN                      NaN
# ...              ...       ...    ...                      ...
# 862919           NaN       NaN    NaN                      NaN
# 862920           NaN       NaN    NaN                      NaN
# 862921           NaN       NaN    NaN                      NaN
# 862922           NaN       NaN    NaN                      NaN
# 862923           NaN       NaN    NaN                      NaN
#
#         Share in % (production)  Share HHI Production  HHI_production  \
# 0                           NaN                   NaN             NaN
# 1                           NaN                   NaN             NaN
# 2                           NaN                   NaN             NaN
# 3                           NaN                   NaN             NaN
# 4                           NaN                   NaN             NaN
# ...                         ...                   ...             ...
# 862919                      NaN                   NaN             NaN
# 862920                      NaN                   NaN             NaN
# 862921                      NaN                   NaN             NaN
# 862922                      NaN                   NaN             NaN
# 862923                      NaN                   NaN             NaN
#
#         HHI_production_scaled typeCode freqCode  refPeriodId  refYear  \
# 0                         NaN      NaN      NaN          NaN      NaN
# 1                         NaN      NaN      NaN          NaN      NaN
# 2                         NaN      NaN      NaN          NaN      NaN
# 3                         NaN      NaN      NaN          NaN      NaN
# 4                         NaN      NaN      NaN          NaN      NaN
# ...                       ...      ...      ...          ...      ...
# 862919                    NaN      NaN      NaN          NaN      NaN
# 862920                    NaN      NaN      NaN          NaN      NaN
# 862921                    NaN      NaN      NaN          NaN      NaN
# 862922                    NaN      NaN      NaN          NaN      NaN
# 862923                    NaN      NaN      NaN          NaN      NaN
#
#         refMonth reporterISO reporterDesc flowCode flowDesc  partnerCode  \
# 0            NaN         NaN          NaN      NaN      NaN          NaN
# 1            NaN         NaN          NaN      NaN      NaN          NaN
# 2            NaN         NaN          NaN      NaN      NaN          NaN
# 3            NaN         NaN          NaN      NaN      NaN          NaN
# 4            NaN         NaN          NaN      NaN      NaN          NaN
# ...          ...         ...          ...      ...      ...          ...
# 862919       NaN         NaN          NaN      NaN      NaN          NaN
# 862920       NaN         NaN          NaN      NaN      NaN          NaN
# 862921       NaN         NaN          NaN      NaN      NaN          NaN
# 862922       NaN         NaN          NaN      NaN      NaN          NaN
# 862923       NaN         NaN          NaN      NaN      NaN          NaN
#
#        partnerISO partnerDesc  partner2Code partner2ISO partner2Desc  \
# 0             NaN         NaN           NaN         NaN          NaN
# 1             NaN         NaN           NaN         NaN          NaN
# 2             NaN         NaN           NaN         NaN          NaN
# 3             NaN         NaN           NaN         NaN          NaN
# 4             NaN         NaN           NaN         NaN          NaN
# ...           ...         ...           ...         ...          ...
# 862919        NaN         NaN           NaN         NaN          NaN
# 862920        NaN         NaN           NaN         NaN          NaN
# 862921        NaN         NaN           NaN         NaN          NaN
# 862922        NaN         NaN           NaN         NaN          NaN
# 862923        NaN         NaN           NaN         NaN          NaN
#
#        classificationCode classificationSearchCode isOriginalClassification  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
# ...                   ...                      ...                      ...
# 862919                NaN                      NaN                      NaN
# 862920                NaN                      NaN                      NaN
# 862921                NaN                      NaN                      NaN
# 862922                NaN                      NaN                      NaN
# 862923                NaN                      NaN                      NaN
#
#        cmdDesc  aggrLevel isLeaf customsCode customsDesc  mosCode  motCode  \
# 0          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 1          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 2          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 3          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 4          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# ...        ...        ...    ...         ...         ...      ...      ...
# 862919     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862920     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862921     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862922     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862923     NaN        NaN    NaN         NaN         NaN      NaN      NaN
#
#        motDesc  qtyUnitCode  qty isQtyEstimated  altQtyUnitCode  \
# 0          NaN          NaN  NaN            NaN             NaN
# 1          NaN          NaN  NaN            NaN             NaN
# 2          NaN          NaN  NaN            NaN             NaN
# 3          NaN          NaN  NaN            NaN             NaN
# 4          NaN          NaN  NaN            NaN             NaN
# ...        ...          ...  ...            ...             ...
# 862919     NaN          NaN  NaN            NaN             NaN
# 862920     NaN          NaN  NaN            NaN             NaN
# 862921     NaN          NaN  NaN            NaN             NaN
# 862922     NaN          NaN  NaN            NaN             NaN
# 862923     NaN          NaN  NaN            NaN             NaN
#
#        altQtyUnitAbbr  altQty isAltQtyEstimated  netWgt isNetWgtEstimated  \
# 0                 NaN     NaN               NaN     NaN               NaN
# 1                 NaN     NaN               NaN     NaN               NaN
# 2                 NaN     NaN               NaN     NaN               NaN
# 3                 NaN     NaN               NaN     NaN               NaN
# 4                 NaN     NaN               NaN     NaN               NaN
# ...               ...     ...               ...     ...               ...
# 862919            NaN     NaN               NaN     NaN               NaN
# 862920            NaN     NaN               NaN     NaN               NaN
# 862921            NaN     NaN               NaN     NaN               NaN
# 862922            NaN     NaN               NaN     NaN               NaN
# 862923            NaN     NaN               NaN     NaN               NaN
#
#         grossWgt isGrossWgtEstimated  cifvalue  fobvalue  primaryValue  \
# 0            NaN                 NaN       NaN       NaN           NaN
# 1            NaN                 NaN       NaN       NaN           NaN
# 2            NaN                 NaN       NaN       NaN           NaN
# 3            NaN                 NaN       NaN       NaN           NaN
# 4            NaN                 NaN       NaN       NaN           NaN
# ...          ...                 ...       ...       ...           ...
# 862919       NaN                 NaN       NaN       NaN           NaN
# 862920       NaN                 NaN       NaN       NaN           NaN
# 862921       NaN                 NaN       NaN       NaN           NaN
# 862922       NaN                 NaN       NaN       NaN           NaN
# 862923       NaN                 NaN       NaN       NaN           NaN
#
#         legacyEstimationFlag isReported isAggregate Product_y  \
# 0                        NaN        NaN         NaN       NaN
# 1                        NaN        NaN         NaN       NaN
# 2                        NaN        NaN         NaN       NaN
# 3                        NaN        NaN         NaN       NaN
# 4                        NaN        NaN         NaN       NaN
# ...                      ...        ...         ...       ...
# 862919                   NaN        NaN         NaN       NaN
# 862920                   NaN        NaN         NaN       NaN
# 862921                   NaN        NaN         NaN       NaN
# 862922                   NaN        NaN         NaN       NaN
# 862923                   NaN        NaN         NaN       NaN
#
#         Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 0                            NaN                   NaN                NaN
# 1                            NaN                   NaN                NaN
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                            NaN                   NaN                NaN
# ...                          ...                   ...                ...
# 862919                       NaN                   NaN                NaN
# 862920                       NaN                   NaN                NaN
# 862921                       NaN                   NaN                NaN
# 862922                       NaN                   NaN                NaN
# 862923                       NaN                   NaN                NaN
#
#         HHI_exports  HHI_exports_scaled  partnerCode_import partnerISO_import  \
# 0               NaN                 NaN                 NaN               NaN
# 1               NaN                 NaN                 NaN               NaN
# 2               NaN                 NaN                 NaN               NaN
# 3               NaN                 NaN                 NaN               NaN
# 4               NaN                 NaN                 NaN               NaN
# ...             ...                 ...                 ...               ...
# 862919          NaN                 NaN                 0.0               W00
# 862920          NaN                 NaN               380.0               ITA
# 862921          NaN                 NaN               710.0               ZAF
# 862922          NaN                 NaN               710.0               ZAF
# 862923          NaN                 NaN                 0.0               W00
#
#        partnerDesc_import  qty_import  netWgt_import qtyUnitAbbr_import  \
# 0                     NaN         NaN            NaN                NaN
# 1                     NaN         NaN            NaN                NaN
# 2                     NaN         NaN            NaN                NaN
# 3                     NaN         NaN            NaN                NaN
# 4                     NaN         NaN            NaN                NaN
# ...                   ...         ...            ...                ...
# 862919              World     63000.0        63000.0                 kg
# 862920              Italy     30000.0        30000.0                 kg
# 862921       South Africa     33000.0        33000.0                 kg
# 862922       South Africa         0.0            0.0                NaN
# 862923              World         0.0            0.0                NaN
#
#         cifvalue_import  primaryValue_import  netWgt_total_import  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 862919        26944.376            26944.376              63000.0
# 862920         9204.315             9204.315              63000.0
# 862921        17740.061            17740.061              63000.0
# 862922       845145.046           845145.046                  0.0
# 862923       845145.046           845145.046                  0.0
#
#         cifvalue_total_import  primaryValue_total_import
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 862919              26944.376                  26944.376
# 862920              26944.376                  26944.376
# 862921              26944.376                  26944.376
# 862922             845145.046                 845145.046
# 862923             845145.046                 845145.046
#
# [862924 rows x 93 columns]

# %%
all_data_df["Geopolitical Risk Production"] = all_data_df["HHI_production"] * (all_data_df["EGSEHI_6root"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Exports"] = all_data_df["HHI_exports"] * (all_data_df["EGSEHI_6root"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Only Political Stability Production"] = all_data_df["HHI_production"] * (all_data_df["value_governance_isolated"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Only Political Stability Exports"] = all_data_df["HHI_exports"] * (all_data_df["value_governance_isolated"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))

all_data_df["Geopolitical Risk Production NO-ROOT"] = all_data_df["HHI_production"] * (all_data_df["EGSEHI"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))
all_data_df["Geopolitical Risk Exports NO-ROOT"] = all_data_df["HHI_exports"] * (all_data_df["EGSEHI"] * all_data_df["netWgt_import"] / (all_data_df["Total_value_YearProduct"] + all_data_df["netWgt_total_import"]))

# %%
all_data_df
# Out:
#           Country              Product   cmdCode Source  Year  \
# 0         ALBANIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 1         ALGERIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 2       ARGENTINA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 3       AUSTRALIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# 4         AUSTRIA  IRON ORE (FE-CONT.)    2601.0    org  1984
# ...           ...                  ...       ...    ...   ...
# 862919        NaN                  NaN  261510.0    NaN  2020
# 862920        NaN                  NaN  261510.0    NaN  2020
# 862921        NaN                  NaN  261510.0    NaN  2020
# 862922        NaN                  NaN  261510.0    NaN  2020
# 862923        NaN                  NaN  261510.0    NaN  2020
#
#         Domestic Production Value (P_AC)  Value (Ton) qtyUnitAbbr  \
# 0                           4.395020e+08     439502.0          kg
# 1                           2.000000e+09    2000000.0          kg
# 2                           3.455760e+08     345576.0          kg
# 3                           5.688500e+10   56885000.0          kg
# 4                           1.137872e+09    1137872.0          kg
# ...                                  ...          ...         ...
# 862919                               NaN          NaN         NaN
# 862920                               NaN          NaN         NaN
# 862921                               NaN          NaN         NaN
# 862922                               NaN          NaN         NaN
# 862923                               NaN          NaN         NaN
#
#         reporterCode ISO3  value_economic no_value_economic  value_governance  \
# 0                8.0  NaN             NaN               NaN               NaN
# 1               12.0  NaN             NaN               NaN               NaN
# 2               32.0  NaN             NaN               NaN               NaN
# 3               36.0  NaN             NaN               NaN               NaN
# 4               40.0  NaN             NaN               NaN               NaN
# ...              ...  ...             ...               ...               ...
# 862919         894.0  NaN             NaN               NaN               NaN
# 862920         894.0  NaN             NaN               NaN               NaN
# 862921         894.0  NaN             NaN               NaN               NaN
# 862922         716.0  NaN             NaN               NaN               NaN
# 862923         716.0  NaN             NaN               NaN               NaN
#
#        no_value_governance  value_social no_value_social  value_ecosystems  \
# 0                      NaN           NaN             NaN               NaN
# 1                      NaN           NaN             NaN               NaN
# 2                      NaN           NaN             NaN               NaN
# 3                      NaN           NaN             NaN               NaN
# 4                      NaN           NaN             NaN               NaN
# ...                    ...           ...             ...               ...
# 862919                 NaN           NaN             NaN               NaN
# 862920                 NaN           NaN             NaN               NaN
# 862921                 NaN           NaN             NaN               NaN
# 862922                 NaN           NaN             NaN               NaN
# 862923                 NaN           NaN             NaN               NaN
#
#        no_value_ecosystems  value_habitat no_value_habitat  \
# 0                      NaN            NaN              NaN
# 1                      NaN            NaN              NaN
# 2                      NaN            NaN              NaN
# 3                      NaN            NaN              NaN
# 4                      NaN            NaN              NaN
# ...                    ...            ...              ...
# 862919                 NaN            NaN              NaN
# 862920                 NaN            NaN              NaN
# 862921                 NaN            NaN              NaN
# 862922                 NaN            NaN              NaN
# 862923                 NaN            NaN              NaN
#
#         value_infrastructure no_value_infrastructure  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 862919                   NaN                     NaN
# 862920                   NaN                     NaN
# 862921                   NaN                     NaN
# 862922                   NaN                     NaN
# 862923                   NaN                     NaN
#
#         value_governance_isolated no_value_governance_isolated  EGSEHI  \
# 0                             NaN                          NaN     NaN
# 1                             NaN                          NaN     NaN
# 2                             NaN                          NaN     NaN
# 3                             NaN                          NaN     NaN
# 4                             NaN                          NaN     NaN
# ...                           ...                          ...     ...
# 862919                        NaN                          NaN     NaN
# 862920                        NaN                          NaN     NaN
# 862921                        NaN                          NaN     NaN
# 862922                        NaN                          NaN     NaN
# 862923                        NaN                          NaN     NaN
#
#         EGSEHI_6root Product_x  Value  Total_value_YearProduct  \
# 0                NaN       NaN    NaN                      NaN
# 1                NaN       NaN    NaN                      NaN
# 2                NaN       NaN    NaN                      NaN
# 3                NaN       NaN    NaN                      NaN
# 4                NaN       NaN    NaN                      NaN
# ...              ...       ...    ...                      ...
# 862919           NaN       NaN    NaN                      NaN
# 862920           NaN       NaN    NaN                      NaN
# 862921           NaN       NaN    NaN                      NaN
# 862922           NaN       NaN    NaN                      NaN
# 862923           NaN       NaN    NaN                      NaN
#
#         Share in % (production)  Share HHI Production  HHI_production  \
# 0                           NaN                   NaN             NaN
# 1                           NaN                   NaN             NaN
# 2                           NaN                   NaN             NaN
# 3                           NaN                   NaN             NaN
# 4                           NaN                   NaN             NaN
# ...                         ...                   ...             ...
# 862919                      NaN                   NaN             NaN
# 862920                      NaN                   NaN             NaN
# 862921                      NaN                   NaN             NaN
# 862922                      NaN                   NaN             NaN
# 862923                      NaN                   NaN             NaN
#
#         HHI_production_scaled typeCode freqCode  refPeriodId  refYear  \
# 0                         NaN      NaN      NaN          NaN      NaN
# 1                         NaN      NaN      NaN          NaN      NaN
# 2                         NaN      NaN      NaN          NaN      NaN
# 3                         NaN      NaN      NaN          NaN      NaN
# 4                         NaN      NaN      NaN          NaN      NaN
# ...                       ...      ...      ...          ...      ...
# 862919                    NaN      NaN      NaN          NaN      NaN
# 862920                    NaN      NaN      NaN          NaN      NaN
# 862921                    NaN      NaN      NaN          NaN      NaN
# 862922                    NaN      NaN      NaN          NaN      NaN
# 862923                    NaN      NaN      NaN          NaN      NaN
#
#         refMonth reporterISO reporterDesc flowCode flowDesc  partnerCode  \
# 0            NaN         NaN          NaN      NaN      NaN          NaN
# 1            NaN         NaN          NaN      NaN      NaN          NaN
# 2            NaN         NaN          NaN      NaN      NaN          NaN
# 3            NaN         NaN          NaN      NaN      NaN          NaN
# 4            NaN         NaN          NaN      NaN      NaN          NaN
# ...          ...         ...          ...      ...      ...          ...
# 862919       NaN         NaN          NaN      NaN      NaN          NaN
# 862920       NaN         NaN          NaN      NaN      NaN          NaN
# 862921       NaN         NaN          NaN      NaN      NaN          NaN
# 862922       NaN         NaN          NaN      NaN      NaN          NaN
# 862923       NaN         NaN          NaN      NaN      NaN          NaN
#
#        partnerISO partnerDesc  partner2Code partner2ISO partner2Desc  \
# 0             NaN         NaN           NaN         NaN          NaN
# 1             NaN         NaN           NaN         NaN          NaN
# 2             NaN         NaN           NaN         NaN          NaN
# 3             NaN         NaN           NaN         NaN          NaN
# 4             NaN         NaN           NaN         NaN          NaN
# ...           ...         ...           ...         ...          ...
# 862919        NaN         NaN           NaN         NaN          NaN
# 862920        NaN         NaN           NaN         NaN          NaN
# 862921        NaN         NaN           NaN         NaN          NaN
# 862922        NaN         NaN           NaN         NaN          NaN
# 862923        NaN         NaN           NaN         NaN          NaN
#
#        classificationCode classificationSearchCode isOriginalClassification  \
# 0                     NaN                      NaN                      NaN
# 1                     NaN                      NaN                      NaN
# 2                     NaN                      NaN                      NaN
# 3                     NaN                      NaN                      NaN
# 4                     NaN                      NaN                      NaN
# ...                   ...                      ...                      ...
# 862919                NaN                      NaN                      NaN
# 862920                NaN                      NaN                      NaN
# 862921                NaN                      NaN                      NaN
# 862922                NaN                      NaN                      NaN
# 862923                NaN                      NaN                      NaN
#
#        cmdDesc  aggrLevel isLeaf customsCode customsDesc  mosCode  motCode  \
# 0          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 1          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 2          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 3          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 4          NaN        NaN    NaN         NaN         NaN      NaN      NaN
# ...        ...        ...    ...         ...         ...      ...      ...
# 862919     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862920     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862921     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862922     NaN        NaN    NaN         NaN         NaN      NaN      NaN
# 862923     NaN        NaN    NaN         NaN         NaN      NaN      NaN
#
#        motDesc  qtyUnitCode  qty isQtyEstimated  altQtyUnitCode  \
# 0          NaN          NaN  NaN            NaN             NaN
# 1          NaN          NaN  NaN            NaN             NaN
# 2          NaN          NaN  NaN            NaN             NaN
# 3          NaN          NaN  NaN            NaN             NaN
# 4          NaN          NaN  NaN            NaN             NaN
# ...        ...          ...  ...            ...             ...
# 862919     NaN          NaN  NaN            NaN             NaN
# 862920     NaN          NaN  NaN            NaN             NaN
# 862921     NaN          NaN  NaN            NaN             NaN
# 862922     NaN          NaN  NaN            NaN             NaN
# 862923     NaN          NaN  NaN            NaN             NaN
#
#        altQtyUnitAbbr  altQty isAltQtyEstimated  netWgt isNetWgtEstimated  \
# 0                 NaN     NaN               NaN     NaN               NaN
# 1                 NaN     NaN               NaN     NaN               NaN
# 2                 NaN     NaN               NaN     NaN               NaN
# 3                 NaN     NaN               NaN     NaN               NaN
# 4                 NaN     NaN               NaN     NaN               NaN
# ...               ...     ...               ...     ...               ...
# 862919            NaN     NaN               NaN     NaN               NaN
# 862920            NaN     NaN               NaN     NaN               NaN
# 862921            NaN     NaN               NaN     NaN               NaN
# 862922            NaN     NaN               NaN     NaN               NaN
# 862923            NaN     NaN               NaN     NaN               NaN
#
#         grossWgt isGrossWgtEstimated  cifvalue  fobvalue  primaryValue  \
# 0            NaN                 NaN       NaN       NaN           NaN
# 1            NaN                 NaN       NaN       NaN           NaN
# 2            NaN                 NaN       NaN       NaN           NaN
# 3            NaN                 NaN       NaN       NaN           NaN
# 4            NaN                 NaN       NaN       NaN           NaN
# ...          ...                 ...       ...       ...           ...
# 862919       NaN                 NaN       NaN       NaN           NaN
# 862920       NaN                 NaN       NaN       NaN           NaN
# 862921       NaN                 NaN       NaN       NaN           NaN
# 862922       NaN                 NaN       NaN       NaN           NaN
# 862923       NaN                 NaN       NaN       NaN           NaN
#
#         legacyEstimationFlag isReported isAggregate Product_y  \
# 0                        NaN        NaN         NaN       NaN
# 1                        NaN        NaN         NaN       NaN
# 2                        NaN        NaN         NaN       NaN
# 3                        NaN        NaN         NaN       NaN
# 4                        NaN        NaN         NaN       NaN
# ...                      ...        ...         ...       ...
# 862919                   NaN        NaN         NaN       NaN
# 862920                   NaN        NaN         NaN       NaN
# 862921                   NaN        NaN         NaN       NaN
# 862922                   NaN        NaN         NaN       NaN
# 862923                   NaN        NaN         NaN       NaN
#
#         Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 0                            NaN                   NaN                NaN
# 1                            NaN                   NaN                NaN
# 2                            NaN                   NaN                NaN
# 3                            NaN                   NaN                NaN
# 4                            NaN                   NaN                NaN
# ...                          ...                   ...                ...
# 862919                       NaN                   NaN                NaN
# 862920                       NaN                   NaN                NaN
# 862921                       NaN                   NaN                NaN
# 862922                       NaN                   NaN                NaN
# 862923                       NaN                   NaN                NaN
#
#         HHI_exports  HHI_exports_scaled  partnerCode_import partnerISO_import  \
# 0               NaN                 NaN                 NaN               NaN
# 1               NaN                 NaN                 NaN               NaN
# 2               NaN                 NaN                 NaN               NaN
# 3               NaN                 NaN                 NaN               NaN
# 4               NaN                 NaN                 NaN               NaN
# ...             ...                 ...                 ...               ...
# 862919          NaN                 NaN                 0.0               W00
# 862920          NaN                 NaN               380.0               ITA
# 862921          NaN                 NaN               710.0               ZAF
# 862922          NaN                 NaN               710.0               ZAF
# 862923          NaN                 NaN                 0.0               W00
#
#        partnerDesc_import  qty_import  netWgt_import qtyUnitAbbr_import  \
# 0                     NaN         NaN            NaN                NaN
# 1                     NaN         NaN            NaN                NaN
# 2                     NaN         NaN            NaN                NaN
# 3                     NaN         NaN            NaN                NaN
# 4                     NaN         NaN            NaN                NaN
# ...                   ...         ...            ...                ...
# 862919              World     63000.0        63000.0                 kg
# 862920              Italy     30000.0        30000.0                 kg
# 862921       South Africa     33000.0        33000.0                 kg
# 862922       South Africa         0.0            0.0                NaN
# 862923              World         0.0            0.0                NaN
#
#         cifvalue_import  primaryValue_import  netWgt_total_import  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ...                 ...                  ...                  ...
# 862919        26944.376            26944.376              63000.0
# 862920         9204.315             9204.315              63000.0
# 862921        17740.061            17740.061              63000.0
# 862922       845145.046           845145.046                  0.0
# 862923       845145.046           845145.046                  0.0
#
#         cifvalue_total_import  primaryValue_total_import  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 862919              26944.376                  26944.376
# 862920              26944.376                  26944.376
# 862921              26944.376                  26944.376
# 862922             845145.046                 845145.046
# 862923             845145.046                 845145.046
#
#         Geopolitical Risk Production  Geopolitical Risk Exports  \
# 0                                NaN                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
# ...                              ...                        ...
# 862919                           NaN                        NaN
# 862920                           NaN                        NaN
# 862921                           NaN                        NaN
# 862922                           NaN                        NaN
# 862923                           NaN                        NaN
#
#         Geopolitical Risk Only Political Stability Production  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 862919                                                NaN
# 862920                                                NaN
# 862921                                                NaN
# 862922                                                NaN
# 862923                                                NaN
#
#         Geopolitical Risk Only Political Stability Exports  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 862919                                                NaN
# 862920                                                NaN
# 862921                                                NaN
# 862922                                                NaN
# 862923                                                NaN
#
#         Geopolitical Risk Production NO-ROOT  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 862919                                   NaN
# 862920                                   NaN
# 862921                                   NaN
# 862922                                   NaN
# 862923                                   NaN
#
#         Geopolitical Risk Exports NO-ROOT
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 862919                                NaN
# 862920                                NaN
# 862921                                NaN
# 862922                                NaN
# 862923                                NaN
#
# [862924 rows x 99 columns]

# %% [markdown]
# ### Extra CSV: Data without "World" entries (Import)

# %%
all_data_noWorld_df = all_data_df[all_data_df["partnerDesc_import"] != "World"]
all_data_noWorld_df.shape
# Out:
# (804236, 99)

# %% [markdown]
# ## Extra CSV: Dataframe that contains data in imports and exports risk value

# %%
all_data_no_nulls_df = all_data_df[(~all_data_df["Geopolitical Risk Production"].isna()) & ~all_data_df["Geopolitical Risk Exports"].isna()]
all_data_no_nulls_noWorld_df = all_data_noWorld_df[(~all_data_noWorld_df["Geopolitical Risk Production"].isna()) & ~all_data_noWorld_df["Geopolitical Risk Exports"].isna()]
all_data_no_nulls_df.shape
# Out:
# (128874, 99)

# %% [markdown]
# ## Save results

# %%
all_data_df.to_csv("../data/all_consolidated_data/all_consolidated_data.csv", index=False)
all_data_noWorld_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noWorld.csv", index=False)

# %%
all_data_no_nulls_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noNulls.csv", index=True)
all_data_no_nulls_noWorld_df.to_csv("../data/all_consolidated_data/all_consolidated_data_noNulls_noWorld.csv", index=True)
