# %%
import pandas as pd
from wits_consumer import WitsConsumer

# %%
# # Necessary in case your production file does not match with current list of country/code
# https://comtrade.un.org/Data/cache/reporterAreas.json

# wc = WitsConsumer()
# country_codes = wc.get_list_iso3codes()
# country_codes

# %% [markdown]
# ## Now HHI for production

# %%
df_production = pd.read_csv("../../data/Production/Production_one_file_2.csv")

# %%
# df_production["Country"] = df_production["Country"].str.upper()
# df_production["Product"] = df_production["Product"].str.upper()
df_production["Year"] = df_production["Year"].apply(int).apply(str)
df_production
# Out:
#              Country               Product   cmdCode Source  Year  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode
# 0      4.395020e+08     439502.0          kg           8.0
# 1      2.000000e+09    2000000.0          kg          12.0
# 2      3.455760e+08     345576.0          kg          32.0
# 3      5.688500e+10   56885000.0          kg          36.0
# 4      1.137872e+09    1137872.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
# [96385 rows x 9 columns]

# %%
df_production_summarized = df_production.groupby(["Year", "Product"])[["Value"]].sum().reset_index()
df_production_summarized.rename(columns={"Value": "Total_value_YearProduct"}, inplace=True)
df_production_summarized
# Out:
#       Year                Product  Total_value_YearProduct
# 0     1984              ALUMINIUM             1.684394e+10
# 1     1984               ANTIMONY             5.773100e+07
# 2     1984  ARSENIC (AS2O3-CONT.)             3.869100e+07
# 3     1984               ASBESTOS             4.268221e+09
# 4     1984                 BARYTE             7.313479e+09
# ...    ...                    ...                      ...
# 2474  2020   URANIUM (U3O8-CONT.)             5.626900e+07
# 2475  2020     VANADIUM (V-CONT.)             1.057760e+08
# 2476  2020            VERMICULITE             4.166380e+08
# 2477  2020                   ZINC             1.260830e+10
# 2478  2020         ZIRCON (CONC.)             1.235632e+09
#
# [2479 rows x 3 columns]

# %% [markdown]
# ### Let's left-join production and total value of production by (Year, Product)

# %%
df = pd.merge(df_production, df_production_summarized, how="left", left_on=["Year", "Product"], right_on=["Year", "Product"])
df
# Out:
#              Country               Product   cmdCode Source  Year  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode  \
# 0      4.395020e+08     439502.0          kg           8.0
# 1      2.000000e+09    2000000.0          kg          12.0
# 2      3.455760e+08     345576.0          kg          32.0
# 3      5.688500e+10   56885000.0          kg          36.0
# 4      1.137872e+09    1137872.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
#        Total_value_YearProduct
# 0                 4.468878e+11
# 1                 4.468878e+11
# 2                 4.468878e+11
# 3                 4.468878e+11
# 4                 4.468878e+11
# ...                        ...
# 96380             5.626900e+07
# 96381             5.626900e+07
# 96382             5.626900e+07
# 96383             5.626900e+07
# 96384             5.626900e+07
#
# [96385 rows x 10 columns]

# %%
df["Share in %"] = df["Value"] * 100 / df["Total_value_YearProduct"]
df["Share HHI Production"] = df["Share in %"] ** 2
df
# Out:
#              Country               Product   cmdCode Source  Year  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode  \
# 0      4.395020e+08     439502.0          kg           8.0
# 1      2.000000e+09    2000000.0          kg          12.0
# 2      3.455760e+08     345576.0          kg          32.0
# 3      5.688500e+10   56885000.0          kg          36.0
# 4      1.137872e+09    1137872.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
#        Total_value_YearProduct  Share in %  Share HHI Production
# 0                 4.468878e+11    0.098347              0.009672
# 1                 4.468878e+11    0.447540              0.200292
# 2                 4.468878e+11    0.077329              0.005980
# 3                 4.468878e+11   12.729145            162.031127
# 4                 4.468878e+11    0.254621              0.064832
# ...                        ...         ...                   ...
# 96380             5.626900e+07         NaN                   NaN
# 96381             5.626900e+07    1.558585              2.429186
# 96382             5.626900e+07    0.012440              0.000155
# 96383             5.626900e+07    7.334411             53.793592
# 96384             5.626900e+07         NaN                   NaN
#
# [96385 rows x 12 columns]

# %% [markdown]
# ### Sum the "Share HHI Production" by (Year, Product) and you get the HHI index :)

# %%
df_hhi_production = df.groupby(["Year", "Product"])[["Share HHI Production"]].sum().reset_index()
df_hhi_production.rename(columns={"Share HHI Production": "HHI_production"}, inplace=True)
df_hhi_production = pd.merge(df, df_hhi_production, how="left", left_on=["Year", "Product"], right_on=["Year", "Product"])
df_hhi_production
# CONSIDERATIONS
# - Currently the HHI value is pasted to the row even if the production is null. Shall we replace by NANs if production is null?
# Out:
#              Country               Product   cmdCode Source  Year  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode  \
# 0      4.395020e+08     439502.0          kg           8.0
# 1      2.000000e+09    2000000.0          kg          12.0
# 2      3.455760e+08     345576.0          kg          32.0
# 3      5.688500e+10   56885000.0          kg          36.0
# 4      1.137872e+09    1137872.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
#        Total_value_YearProduct  Share in %  Share HHI Production  \
# 0                 4.468878e+11    0.098347              0.009672
# 1                 4.468878e+11    0.447540              0.200292
# 2                 4.468878e+11    0.077329              0.005980
# 3                 4.468878e+11   12.729145            162.031127
# 4                 4.468878e+11    0.254621              0.064832
# ...                        ...         ...                   ...
# 96380             5.626900e+07         NaN                   NaN
# 96381             5.626900e+07    1.558585              2.429186
# 96382             5.626900e+07    0.012440              0.000155
# 96383             5.626900e+07    7.334411             53.793592
# 96384             5.626900e+07         NaN                   NaN
#
#        HHI_production
# 0         1518.338731
# 1         1518.338731
# 2         1518.338731
# 3         1518.338731
# 4         1518.338731
# ...               ...
# 96380     2182.434818
# 96381     2182.434818
# 96382     2182.434818
# 96383     2182.434818
# 96384     2182.434818
#
# [96385 rows x 13 columns]

# %% [markdown]
# ### NEW: Scale HHI_Production between [0,1]

# %%
# max_value is 10,000 and is canada for selenium. It's the only one country that produces seleniun
max_hhi = df_hhi_production["HHI_production"].max()
min_hhi = df_hhi_production["HHI_production"].min()
df_hhi_production["HHI_production_scaled"] = (df_hhi_production["HHI_production"] - min_hhi) / (max_hhi - min_hhi)
df_hhi_production
# Out:
#              Country               Product   cmdCode Source  Year  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  1984
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode  \
# 0      4.395020e+08     439502.0          kg           8.0
# 1      2.000000e+09    2000000.0          kg          12.0
# 2      3.455760e+08     345576.0          kg          32.0
# 3      5.688500e+10   56885000.0          kg          36.0
# 4      1.137872e+09    1137872.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
#        Total_value_YearProduct  Share in %  Share HHI Production  \
# 0                 4.468878e+11    0.098347              0.009672
# 1                 4.468878e+11    0.447540              0.200292
# 2                 4.468878e+11    0.077329              0.005980
# 3                 4.468878e+11   12.729145            162.031127
# 4                 4.468878e+11    0.254621              0.064832
# ...                        ...         ...                   ...
# 96380             5.626900e+07         NaN                   NaN
# 96381             5.626900e+07    1.558585              2.429186
# 96382             5.626900e+07    0.012440              0.000155
# 96383             5.626900e+07    7.334411             53.793592
# 96384             5.626900e+07         NaN                   NaN
#
#        HHI_production  HHI_production_scaled
# 0         1518.338731               0.151834
# 1         1518.338731               0.151834
# 2         1518.338731               0.151834
# 3         1518.338731               0.151834
# 4         1518.338731               0.151834
# ...               ...                    ...
# 96380     2182.434818               0.218243
# 96381     2182.434818               0.218243
# 96382     2182.434818               0.218243
# 96383     2182.434818               0.218243
# 96384     2182.434818               0.218243
#
# [96385 rows x 14 columns]

# %%
df_hhi_production.to_csv("../../data/hhi_data/df_hhi_production.csv", index=False)

# %% [markdown]
# ### Now only consider entries where year >= 2000

# %%
# Remove all the rows where year < 2000
df_hhi_production_2000s =df_hhi_production[df_hhi_production["Year"].apply(int) >= 2000]

# %%
# max_value is 10,000 and is canada for selenium. It's the only one country that produces seleniun
max_hhi = df_hhi_production_2000s["HHI_production"].max()
min_hhi = df_hhi_production_2000s["HHI_production"].min()
df_hhi_production_2000s["HHI_production_scaled"] = (df_hhi_production_2000s["HHI_production"] - min_hhi) / (max_hhi - min_hhi)
df_hhi_production_2000s
# Out:
# c:\Users\zacat\OneDrive\Documentos\Investigacion\investigacion-gnn-cic\rb_venv3715\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#              Country               Product   cmdCode Source  Year  \
# 1200         ALBANIA   IRON ORE (FE-CONT.)    2601.0    org  2000
# 1201         ALGERIA   IRON ORE (FE-CONT.)    2601.0    org  2000
# 1202       ARGENTINA   IRON ORE (FE-CONT.)    2601.0    org  2000
# 1203       AUSTRALIA   IRON ORE (FE-CONT.)    2601.0    org  2000
# 1204         AUSTRIA   IRON ORE (FE-CONT.)    2601.0    org  2000
# ...              ...                   ...       ...    ...   ...
# 96380          SPAIN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96381        UKRAINE  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96382  UNITED STATES  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96383     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210.0    org  2020
# 96384     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210.0    org  2020
#
#               Value  Value (Ton) qtyUnitAbbr  reporterCode  \
# 1200   5.000000e+06       5000.0          kg           8.0
# 1201   7.200000e+08     720000.0          kg          12.0
# 1202   0.000000e+00          0.0          kg          32.0
# 1203   1.077287e+11  107728740.0          kg          36.0
# 1204   5.950240e+08     595024.0          kg          40.0
# ...             ...          ...         ...           ...
# 96380           NaN          NaN          kg         724.0
# 96381  8.770000e+05        877.0          kg         804.0
# 96382  7.000000e+03          7.0          kg         842.0
# 96383  4.127000e+06       4127.0          kg         860.0
# 96384           NaN          NaN          kg         890.0
#
#        Total_value_YearProduct  Share in %  Share HHI Production  \
# 1200              6.058481e+11    0.000825          6.811025e-07
# 1201              6.058481e+11    0.118842          1.412334e-02
# 1202              6.058481e+11    0.000000          0.000000e+00
# 1203              6.058481e+11   17.781476          3.161809e+02
# 1204              6.058481e+11    0.098213          9.645870e-03
# ...                        ...         ...                   ...
# 96380             5.626900e+07         NaN                   NaN
# 96381             5.626900e+07    1.558585          2.429186e+00
# 96382             5.626900e+07    0.012440          1.547596e-04
# 96383             5.626900e+07    7.334411          5.379359e+01
# 96384             5.626900e+07         NaN                   NaN
#
#        HHI_production  HHI_production_scaled
# 1200      1202.379321               0.075656
# 1201      1202.379321               0.075656
# 1202      1202.379321               0.075656
# 1203      1202.379321               0.075656
# 1204      1202.379321               0.075656
# ...               ...                    ...
# 96380     2182.434818               0.182702
# 96381     2182.434818               0.182702
# 96382     2182.434818               0.182702
# 96383     2182.434818               0.182702
# 96384     2182.434818               0.182702
#
# [54705 rows x 14 columns]

# %%
df_hhi_production_2000s[df_hhi_production_2000s["HHI_production"] == df_hhi_production_2000s["HHI_production"].max()]
# Out:
#              Country                  Product  cmdCode Source  Year  \
# 30629      AUSTRALIA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30630         BRAZIL  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30631        BURUNDI  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30632          CHINA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30633    CONGO, D.R.  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30634          INDIA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30635   KOREA, NORTH  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30636     MADAGASCAR  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30637       MALAYSIA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30638        MYANMAR  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30639         RUSSIA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30640   SOUTH AFRICA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30641      SRI LANKA  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30642       THAILAND  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30643  UNITED STATES  RARE EARTHS (REO-CONT.)   2846.0    org  2009
# 30644          ZAIRE  RARE EARTHS (REO-CONT.)   2846.0    org  2009
#
#              Value  Value (Ton) qtyUnitAbbr  reporterCode   reporterDesc  \
# 30629          NaN          NaN          kg          36.0      AUSTRALIA
# 30630     303000.0        303.0          kg          76.0         BRAZIL
# 30631          NaN          NaN          kg         108.0        BURUNDI
# 30632  129400000.0     129400.0          kg         156.0          CHINA
# 30633          NaN          NaN          kg         180.0    CONGO, D.R.
# 30634      16000.0         16.0          kg         699.0          INDIA
# 30635          NaN          NaN          kg         408.0   KOREA, NORTH
# 30636          NaN          NaN          kg         450.0     MADAGASCAR
# 30637      20000.0         20.0          kg         458.0       MALAYSIA
# 30638          NaN          NaN          kg         104.0        MYANMAR
# 30639    1898000.0       1898.0          kg         643.0         RUSSIA
# 30640          NaN          NaN          kg         710.0   SOUTH AFRICA
# 30641          NaN          NaN          kg         144.0      SRI LANKA
# 30642          NaN          NaN          kg         764.0       THAILAND
# 30643          NaN          NaN          kg         842.0  UNITED STATES
# 30644          NaN          NaN          kg           NaN            NaN
#
#        Total_value_YearProduct  Share in %  Share HHI Production  \
# 30629              131637000.0         NaN                   NaN
# 30630              131637000.0    0.230178              0.052982
# 30631              131637000.0         NaN                   NaN
# 30632              131637000.0   98.300630           9663.013812
# 30633              131637000.0         NaN                   NaN
# 30634              131637000.0    0.012155              0.000148
# 30635              131637000.0         NaN                   NaN
# 30636              131637000.0         NaN                   NaN
# 30637              131637000.0    0.015193              0.000231
# 30638              131637000.0         NaN                   NaN
# 30639              131637000.0    1.441844              2.078914
# 30640              131637000.0         NaN                   NaN
# 30641              131637000.0         NaN                   NaN
# 30642              131637000.0         NaN                   NaN
# 30643              131637000.0         NaN                   NaN
# 30644              131637000.0         NaN                   NaN
#
#        HHI_production  HHI_production_scaled
# 30629     9665.146086                    1.0
# 30630     9665.146086                    1.0
# 30631     9665.146086                    1.0
# 30632     9665.146086                    1.0
# 30633     9665.146086                    1.0
# 30634     9665.146086                    1.0
# 30635     9665.146086                    1.0
# 30636     9665.146086                    1.0
# 30637     9665.146086                    1.0
# 30638     9665.146086                    1.0
# 30639     9665.146086                    1.0
# 30640     9665.146086                    1.0
# 30641     9665.146086                    1.0
# 30642     9665.146086                    1.0
# 30643     9665.146086                    1.0
# 30644     9665.146086                    1.0

# %%
df_hhi_production_2000s[df_hhi_production_2000s["HHI_production"] == df_hhi_production_2000s["HHI_production"].min()]
# Out:
#           Country    Product  cmdCode Source  Year     Value  Value (Ton)  \
# 40750     ALBANIA  GOLD (KG)   7108.0    org  2018       NaN          NaN
# 40751     ALGERIA  GOLD (KG)   7108.0    org  2018     286.0        0.286
# 40752   ARGENTINA  GOLD (KG)   7108.0    org  2018   58397.0       58.397
# 40753     ARMENIA  GOLD (KG)   7108.0    org  2018    4967.0        4.967
# 40754   AUSTRALIA  GOLD (KG)   7108.0    org  2018  313028.0      313.028
# ...           ...        ...      ...    ...   ...       ...          ...
# 40864     VIETNAM  GOLD (KG)   7108.0    org  2018     570.0        0.570
# 40865  YUGOSLAVIA  GOLD (KG)   7108.0    org  2018       NaN          NaN
# 40866       ZAIRE  GOLD (KG)   7108.0    org  2018       NaN          NaN
# 40867      ZAMBIA  GOLD (KG)   7108.0    org  2018    4044.0        4.044
# 40868    ZIMBABWE  GOLD (KG)   7108.0    org  2018   35054.0       35.054
#
#       qtyUnitAbbr  reporterCode reporterDesc  Total_value_YearProduct  \
# 40750          kg           8.0      ALBANIA                3384879.0
# 40751          kg          12.0      ALGERIA                3384879.0
# 40752          kg          32.0    ARGENTINA                3384879.0
# 40753          kg          51.0      ARMENIA                3384879.0
# 40754          kg          36.0    AUSTRALIA                3384879.0
# ...           ...           ...          ...                      ...
# 40864          kg         704.0      VIETNAM                3384879.0
# 40865          kg         890.0   YUGOSLAVIA                3384879.0
# 40866          kg           NaN          NaN                3384879.0
# 40867          kg         894.0       ZAMBIA                3384879.0
# 40868          kg         716.0     ZIMBABWE                3384879.0
#
#        Share in %  Share HHI Production  HHI_production  HHI_production_scaled
# 40750         NaN                   NaN      509.720604                    0.0
# 40751    0.008449              0.000071      509.720604                    0.0
# 40752    1.725232              2.976424      509.720604                    0.0
# 40753    0.146741              0.021533      509.720604                    0.0
# 40754    9.247834             85.522439      509.720604                    0.0
# ...           ...                   ...             ...                    ...
# 40864    0.016840              0.000284      509.720604                    0.0
# 40865         NaN                   NaN      509.720604                    0.0
# 40866         NaN                   NaN      509.720604                    0.0
# 40867    0.119473              0.014274      509.720604                    0.0
# 40868    1.035606              1.072479      509.720604                    0.0
#
# [119 rows x 15 columns]

# %%
df_hhi_production_2000s.to_csv("../../data/hhi_data/df_hhi_production_2000.csv", index=False)

# %% [markdown]
# ## Now HHI for exports

# %%
df_exports = pd.read_csv("../../data/exports/exports_consolidated_file.csv")
df_exports.rename(columns={"period": "Year"}, inplace=True)
df_exports
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year  reporterCode  \
# 0            C        A     20000101     2000        52  2000            32
# 1            C        A     20000101     2000        52  2000            40
# 2            C        A     20000101     2000        52  2000            56
# 3            C        A     20000101     2000        52  2000            76
# 4            C        A     20000101     2000        52  2000           100
# ...        ...      ...          ...      ...       ...   ...           ...
# 33144        C        A     20200101     2020        52  2020           792
# 33145        C        A     20200101     2020        52  2020           804
# 33146        C        A     20200101     2020        52  2020           826
# 33147        C        A     20200101     2020        52  2020           834
# 33148        C        A     20200101     2020        52  2020           842
#
#       reporterISO             reporterDesc flowCode  ... isNetWgtEstimated  \
# 0             ARG                Argentina        X  ...             False
# 1             AUT                  Austria        X  ...             False
# 2             BEL                  Belgium        X  ...             False
# 3             BRA                   Brazil        X  ...             False
# 4             BGR                 Bulgaria        X  ...             False
# ...           ...                      ...      ...  ...               ...
# 33144         TUR                  Türkiye        X  ...             False
# 33145         UKR                  Ukraine        X  ...             False
# 33146         GBR           United Kingdom        X  ...             False
# 33147         TZA  United Rep. of Tanzania        X  ...             False
# 33148         USA                      USA        X  ...             False
#
#        grossWgt isGrossWgtEstimated cifvalue      fobvalue  primaryValue  \
# 0           NaN               False      NaN  4.291000e+03  4.291000e+03
# 1           NaN               False      NaN  2.275000e+04  2.275000e+04
# 2           NaN               False      NaN  1.435771e+07  1.435771e+07
# 3           0.0               False      0.0  1.131292e+08  1.131292e+08
# 4           NaN               False      NaN  3.882580e+05  3.882580e+05
# ...         ...                 ...      ...           ...           ...
# 33144       0.0               False      0.0  1.611700e+05  1.611700e+05
# 33145       0.0               False      0.0  2.064597e+07  2.064597e+07
# 33146       0.0               False      0.0  3.896642e+06  3.896642e+06
# 33147       0.0               False      0.0  2.295000e+05  2.295000e+05
# 33148       0.0               False      0.0  3.562715e+07  3.562715e+07
#
#       legacyEstimationFlag isReported isAggregate    Product
# 0                        0      False       False  ALUMINIUM
# 1                        0      False       False  ALUMINIUM
# 2                        0      False       False  ALUMINIUM
# 3                        0      False        True  ALUMINIUM
# 4                        0      False       False  ALUMINIUM
# ...                    ...        ...         ...        ...
# 33144                    0      False        True  ZIRCONIUM
# 33145                    0      False        True  ZIRCONIUM
# 33146                    0      False        True  ZIRCONIUM
# 33147                    0      False        True  ZIRCONIUM
# 33148                    0      False        True  ZIRCONIUM
#
# [33149 rows x 48 columns]

# %%
df_exports_summarized = df_exports.groupby(["Year", "Product"])[["netWgt"]].sum().reset_index()
df_exports_summarized.rename(columns={"netWgt": "Total_netWgt_YearProduct"}, inplace=True)
df_exports_summarized
# Out:
#      Year    Product  Total_netWgt_YearProduct
# 0    2000  ALUMINIUM              1.735930e+10
# 1    2000   ANTIMONY              6.013568e+06
# 2    2000   ASBESTOS              6.939951e+08
# 3    2000    BARYTES              3.441228e+09
# 4    2000    BISMUTH              1.172789e+07
# ..    ...        ...                       ...
# 653  2020   TITANIUM              4.017014e+09
# 654  2020   TUNGSTEN              1.234453e+07
# 655  2020    URANIUM              6.182528e+06
# 656  2020       ZINC              9.635898e+09
# 657  2020  ZIRCONIUM              5.196047e+08
#
# [658 rows x 3 columns]

# %% [markdown]
# ### Let's left-join production and total value of production by (Year, Product)

# %%
df_e = pd.merge(df_exports, df_exports_summarized, how="left", left_on=["Year", "Product"], right_on=["Year", "Product"])
df_e
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year  reporterCode  \
# 0            C        A     20000101     2000        52  2000            32
# 1            C        A     20000101     2000        52  2000            40
# 2            C        A     20000101     2000        52  2000            56
# 3            C        A     20000101     2000        52  2000            76
# 4            C        A     20000101     2000        52  2000           100
# ...        ...      ...          ...      ...       ...   ...           ...
# 33144        C        A     20200101     2020        52  2020           792
# 33145        C        A     20200101     2020        52  2020           804
# 33146        C        A     20200101     2020        52  2020           826
# 33147        C        A     20200101     2020        52  2020           834
# 33148        C        A     20200101     2020        52  2020           842
#
#       reporterISO             reporterDesc flowCode  ... grossWgt  \
# 0             ARG                Argentina        X  ...      NaN
# 1             AUT                  Austria        X  ...      NaN
# 2             BEL                  Belgium        X  ...      NaN
# 3             BRA                   Brazil        X  ...      0.0
# 4             BGR                 Bulgaria        X  ...      NaN
# ...           ...                      ...      ...  ...      ...
# 33144         TUR                  Türkiye        X  ...      0.0
# 33145         UKR                  Ukraine        X  ...      0.0
# 33146         GBR           United Kingdom        X  ...      0.0
# 33147         TZA  United Rep. of Tanzania        X  ...      0.0
# 33148         USA                      USA        X  ...      0.0
#
#        isGrossWgtEstimated cifvalue      fobvalue  primaryValue  \
# 0                    False      NaN  4.291000e+03  4.291000e+03
# 1                    False      NaN  2.275000e+04  2.275000e+04
# 2                    False      NaN  1.435771e+07  1.435771e+07
# 3                    False      0.0  1.131292e+08  1.131292e+08
# 4                    False      NaN  3.882580e+05  3.882580e+05
# ...                    ...      ...           ...           ...
# 33144                False      0.0  1.611700e+05  1.611700e+05
# 33145                False      0.0  2.064597e+07  2.064597e+07
# 33146                False      0.0  3.896642e+06  3.896642e+06
# 33147                False      0.0  2.295000e+05  2.295000e+05
# 33148                False      0.0  3.562715e+07  3.562715e+07
#
#       legacyEstimationFlag isReported isAggregate    Product  \
# 0                        0      False       False  ALUMINIUM
# 1                        0      False       False  ALUMINIUM
# 2                        0      False       False  ALUMINIUM
# 3                        0      False        True  ALUMINIUM
# 4                        0      False       False  ALUMINIUM
# ...                    ...        ...         ...        ...
# 33144                    0      False        True  ZIRCONIUM
# 33145                    0      False        True  ZIRCONIUM
# 33146                    0      False        True  ZIRCONIUM
# 33147                    0      False        True  ZIRCONIUM
# 33148                    0      False        True  ZIRCONIUM
#
#        Total_netWgt_YearProduct
# 0                  1.735930e+10
# 1                  1.735930e+10
# 2                  1.735930e+10
# 3                  1.735930e+10
# 4                  1.735930e+10
# ...                         ...
# 33144              5.196047e+08
# 33145              5.196047e+08
# 33146              5.196047e+08
# 33147              5.196047e+08
# 33148              5.196047e+08
#
# [33149 rows x 49 columns]

# %%
df_e["Share in %"] = df_e["netWgt"] * 100 / df_e["Total_netWgt_YearProduct"]
df_e["Share HHI Exports"] = df_e["Share in %"] ** 2
df_e
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year  reporterCode  \
# 0            C        A     20000101     2000        52  2000            32
# 1            C        A     20000101     2000        52  2000            40
# 2            C        A     20000101     2000        52  2000            56
# 3            C        A     20000101     2000        52  2000            76
# 4            C        A     20000101     2000        52  2000           100
# ...        ...      ...          ...      ...       ...   ...           ...
# 33144        C        A     20200101     2020        52  2020           792
# 33145        C        A     20200101     2020        52  2020           804
# 33146        C        A     20200101     2020        52  2020           826
# 33147        C        A     20200101     2020        52  2020           834
# 33148        C        A     20200101     2020        52  2020           842
#
#       reporterISO             reporterDesc flowCode  ... cifvalue  \
# 0             ARG                Argentina        X  ...      NaN
# 1             AUT                  Austria        X  ...      NaN
# 2             BEL                  Belgium        X  ...      NaN
# 3             BRA                   Brazil        X  ...      0.0
# 4             BGR                 Bulgaria        X  ...      NaN
# ...           ...                      ...      ...  ...      ...
# 33144         TUR                  Türkiye        X  ...      0.0
# 33145         UKR                  Ukraine        X  ...      0.0
# 33146         GBR           United Kingdom        X  ...      0.0
# 33147         TZA  United Rep. of Tanzania        X  ...      0.0
# 33148         USA                      USA        X  ...      0.0
#
#            fobvalue  primaryValue legacyEstimationFlag  isReported  \
# 0      4.291000e+03  4.291000e+03                    0       False
# 1      2.275000e+04  2.275000e+04                    0       False
# 2      1.435771e+07  1.435771e+07                    0       False
# 3      1.131292e+08  1.131292e+08                    0       False
# 4      3.882580e+05  3.882580e+05                    0       False
# ...             ...           ...                  ...         ...
# 33144  1.611700e+05  1.611700e+05                    0       False
# 33145  2.064597e+07  2.064597e+07                    0       False
# 33146  3.896642e+06  3.896642e+06                    0       False
# 33147  2.295000e+05  2.295000e+05                    0       False
# 33148  3.562715e+07  3.562715e+07                    0       False
#
#       isAggregate    Product Total_netWgt_YearProduct Share in %  \
# 0           False  ALUMINIUM             1.735930e+10   0.000081
# 1           False  ALUMINIUM             1.735930e+10   0.000742
# 2           False  ALUMINIUM             1.735930e+10   0.770922
# 3            True  ALUMINIUM             1.735930e+10  23.999830
# 4           False  ALUMINIUM             1.735930e+10   0.005305
# ...           ...        ...                      ...        ...
# 33144        True  ZIRCONIUM             5.196047e+08   0.017397
# 33145        True  ZIRCONIUM             5.196047e+08   3.075473
# 33146        True  ZIRCONIUM             5.196047e+08   0.235409
# 33147        True  ZIRCONIUM             5.196047e+08   0.147227
# 33148        True  ZIRCONIUM             5.196047e+08   4.038193
#
#        Share HHI Exports
# 0           6.504168e-09
# 1           5.505128e-07
# 2           5.943208e-01
# 3           5.759918e+02
# 4           2.814732e-05
# ...                  ...
# 33144       3.026514e-04
# 33145       9.458533e+00
# 33146       5.541738e-02
# 33147       2.167588e-02
# 33148       1.630700e+01
#
# [33149 rows x 51 columns]

# %% [markdown]
# ### Sum the "Share HHI Exports" by (Year, Product) and you get the HHI index :)

# %%
df_hhi_exports = df_e.groupby(["Year", "Product"])[["Share HHI Exports"]].sum().reset_index()
df_hhi_exports.rename(columns={"Share HHI Exports": "HHI_exports"}, inplace=True)
df_hhi_exports = pd.merge(df_e, df_hhi_exports, how="left", left_on=["Year", "Product"], right_on=["Year", "Product"])
df_hhi_exports

# SAME: Currently the HHI value is pasted to the row even if the production is null. Shall we replace by NANs if production is null?
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year  reporterCode  \
# 0            C        A     20000101     2000        52  2000            32
# 1            C        A     20000101     2000        52  2000            40
# 2            C        A     20000101     2000        52  2000            56
# 3            C        A     20000101     2000        52  2000            76
# 4            C        A     20000101     2000        52  2000           100
# ...        ...      ...          ...      ...       ...   ...           ...
# 33144        C        A     20200101     2020        52  2020           792
# 33145        C        A     20200101     2020        52  2020           804
# 33146        C        A     20200101     2020        52  2020           826
# 33147        C        A     20200101     2020        52  2020           834
# 33148        C        A     20200101     2020        52  2020           842
#
#       reporterISO             reporterDesc flowCode  ...      fobvalue  \
# 0             ARG                Argentina        X  ...  4.291000e+03
# 1             AUT                  Austria        X  ...  2.275000e+04
# 2             BEL                  Belgium        X  ...  1.435771e+07
# 3             BRA                   Brazil        X  ...  1.131292e+08
# 4             BGR                 Bulgaria        X  ...  3.882580e+05
# ...           ...                      ...      ...  ...           ...
# 33144         TUR                  Türkiye        X  ...  1.611700e+05
# 33145         UKR                  Ukraine        X  ...  2.064597e+07
# 33146         GBR           United Kingdom        X  ...  3.896642e+06
# 33147         TZA  United Rep. of Tanzania        X  ...  2.295000e+05
# 33148         USA                      USA        X  ...  3.562715e+07
#
#        primaryValue legacyEstimationFlag isReported  isAggregate    Product  \
# 0      4.291000e+03                    0      False        False  ALUMINIUM
# 1      2.275000e+04                    0      False        False  ALUMINIUM
# 2      1.435771e+07                    0      False        False  ALUMINIUM
# 3      1.131292e+08                    0      False         True  ALUMINIUM
# 4      3.882580e+05                    0      False        False  ALUMINIUM
# ...             ...                  ...        ...          ...        ...
# 33144  1.611700e+05                    0      False         True  ZIRCONIUM
# 33145  2.064597e+07                    0      False         True  ZIRCONIUM
# 33146  3.896642e+06                    0      False         True  ZIRCONIUM
# 33147  2.295000e+05                    0      False         True  ZIRCONIUM
# 33148  3.562715e+07                    0      False         True  ZIRCONIUM
#
#       Total_netWgt_YearProduct Share in % Share HHI Exports  HHI_exports
# 0                 1.735930e+10   0.000081      6.504168e-09  2219.749888
# 1                 1.735930e+10   0.000742      5.505128e-07  2219.749888
# 2                 1.735930e+10   0.770922      5.943208e-01  2219.749888
# 3                 1.735930e+10  23.999830      5.759918e+02  2219.749888
# 4                 1.735930e+10   0.005305      2.814732e-05  2219.749888
# ...                        ...        ...               ...          ...
# 33144             5.196047e+08   0.017397      3.026514e-04  1210.445136
# 33145             5.196047e+08   3.075473      9.458533e+00  1210.445136
# 33146             5.196047e+08   0.235409      5.541738e-02  1210.445136
# 33147             5.196047e+08   0.147227      2.167588e-02  1210.445136
# 33148             5.196047e+08   4.038193      1.630700e+01  1210.445136
#
# [33149 rows x 52 columns]

# %% [markdown]
# ### Scale HHI between [0,1]

# %%
# max_value is 10,000 and is canada for selenium. It's the only one country that produces seleniun
max_hhi = df_hhi_exports["HHI_exports"].max()
min_hhi = df_hhi_exports["HHI_exports"].min()
df_hhi_exports["HHI_exports_scaled"] = (df_hhi_exports["HHI_exports"] - min_hhi) / (max_hhi - min_hhi)
df_hhi_exports
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year  reporterCode  \
# 0            C        A     20000101     2000        52  2000            32
# 1            C        A     20000101     2000        52  2000            40
# 2            C        A     20000101     2000        52  2000            56
# 3            C        A     20000101     2000        52  2000            76
# 4            C        A     20000101     2000        52  2000           100
# ...        ...      ...          ...      ...       ...   ...           ...
# 33144        C        A     20200101     2020        52  2020           792
# 33145        C        A     20200101     2020        52  2020           804
# 33146        C        A     20200101     2020        52  2020           826
# 33147        C        A     20200101     2020        52  2020           834
# 33148        C        A     20200101     2020        52  2020           842
#
#       reporterISO             reporterDesc flowCode  ...  primaryValue  \
# 0             ARG                Argentina        X  ...  4.291000e+03
# 1             AUT                  Austria        X  ...  2.275000e+04
# 2             BEL                  Belgium        X  ...  1.435771e+07
# 3             BRA                   Brazil        X  ...  1.131292e+08
# 4             BGR                 Bulgaria        X  ...  3.882580e+05
# ...           ...                      ...      ...  ...           ...
# 33144         TUR                  Türkiye        X  ...  1.611700e+05
# 33145         UKR                  Ukraine        X  ...  2.064597e+07
# 33146         GBR           United Kingdom        X  ...  3.896642e+06
# 33147         TZA  United Rep. of Tanzania        X  ...  2.295000e+05
# 33148         USA                      USA        X  ...  3.562715e+07
#
#        legacyEstimationFlag isReported isAggregate    Product  \
# 0                         0      False       False  ALUMINIUM
# 1                         0      False       False  ALUMINIUM
# 2                         0      False       False  ALUMINIUM
# 3                         0      False        True  ALUMINIUM
# 4                         0      False       False  ALUMINIUM
# ...                     ...        ...         ...        ...
# 33144                     0      False        True  ZIRCONIUM
# 33145                     0      False        True  ZIRCONIUM
# 33146                     0      False        True  ZIRCONIUM
# 33147                     0      False        True  ZIRCONIUM
# 33148                     0      False        True  ZIRCONIUM
#
#       Total_netWgt_YearProduct Share in % Share HHI Exports  HHI_exports  \
# 0                 1.735930e+10   0.000081      6.504168e-09  2219.749888
# 1                 1.735930e+10   0.000742      5.505128e-07  2219.749888
# 2                 1.735930e+10   0.770922      5.943208e-01  2219.749888
# 3                 1.735930e+10  23.999830      5.759918e+02  2219.749888
# 4                 1.735930e+10   0.005305      2.814732e-05  2219.749888
# ...                        ...        ...               ...          ...
# 33144             5.196047e+08   0.017397      3.026514e-04  1210.445136
# 33145             5.196047e+08   3.075473      9.458533e+00  1210.445136
# 33146             5.196047e+08   0.235409      5.541738e-02  1210.445136
# 33147             5.196047e+08   0.147227      2.167588e-02  1210.445136
# 33148             5.196047e+08   4.038193      1.630700e+01  1210.445136
#
#        HHI_exports_scaled
# 0                0.164204
# 1                0.164204
# 2                0.164204
# 3                0.164204
# 4                0.164204
# ...                   ...
# 33144            0.052793
# 33145            0.052793
# 33146            0.052793
# 33147            0.052793
# 33148            0.052793
#
# [33149 rows x 53 columns]

# %%
df_hhi_exports.to_csv("../../data/hhi_data/df_hhi_exports.csv", index=False)

# %% [markdown]
# ## Now join data from both HHI dataframes

# %%
pd.set_option('display.max_columns', None)

# %%
df_hhi_production = pd.read_csv("../../data/hhi_data/df_hhi_production_2000.csv")
df_hhi_exports = pd.read_csv("../../data/hhi_data/df_hhi_exports.csv")

# %%
df_hhi_production.loc[df_hhi_production["reporterCode"].notnull(), 'reporterCode'] = df_hhi_production.loc[df_hhi_production['reporterCode'].notnull(), 'reporterCode'].apply(int).apply(str)
df_hhi_production.loc[df_hhi_production["cmdCode"].notnull(), 'cmdCode'] = df_hhi_production.loc[df_hhi_production['cmdCode'].notnull(), 'cmdCode'].apply(int).apply(str)
df_hhi_production.rename(columns={"Share in %": "Share in % (production)"}, inplace=True)
df_hhi_production
# Out:
#              Country               Product cmdCode Source  Year         Value  \
# 0            ALBANIA   IRON ORE (FE-CONT.)    2601    org  2000  5.000000e+06
# 1            ALGERIA   IRON ORE (FE-CONT.)    2601    org  2000  7.200000e+08
# 2          ARGENTINA   IRON ORE (FE-CONT.)    2601    org  2000  0.000000e+00
# 3          AUSTRALIA   IRON ORE (FE-CONT.)    2601    org  2000  1.077287e+11
# 4            AUSTRIA   IRON ORE (FE-CONT.)    2601    org  2000  5.950240e+08
# ...              ...                   ...     ...    ...   ...           ...
# 54700          SPAIN  URANIUM (U3O8-CONT.)  261210    org  2020           NaN
# 54701        UKRAINE  URANIUM (U3O8-CONT.)  261210    org  2020  8.770000e+05
# 54702  UNITED STATES  URANIUM (U3O8-CONT.)  261210    org  2020  7.000000e+03
# 54703     UZBEKISTAN  URANIUM (U3O8-CONT.)  261210    org  2020  4.127000e+06
# 54704     YUGOSLAVIA  URANIUM (U3O8-CONT.)  261210    org  2020           NaN
#
#        Value (Ton) qtyUnitAbbr reporterCode  Total_value_YearProduct  \
# 0           5000.0          kg            8             6.058481e+11
# 1         720000.0          kg           12             6.058481e+11
# 2              0.0          kg           32             6.058481e+11
# 3      107728740.0          kg           36             6.058481e+11
# 4         595024.0          kg           40             6.058481e+11
# ...            ...         ...          ...                      ...
# 54700          NaN          kg          724             5.626900e+07
# 54701        877.0          kg          804             5.626900e+07
# 54702          7.0          kg          842             5.626900e+07
# 54703       4127.0          kg          860             5.626900e+07
# 54704          NaN          kg          890             5.626900e+07
#
#        Share in % (production)  Share HHI Production  HHI_production  \
# 0                     0.000825          6.811025e-07     1202.379321
# 1                     0.118842          1.412334e-02     1202.379321
# 2                     0.000000          0.000000e+00     1202.379321
# 3                    17.781476          3.161809e+02     1202.379321
# 4                     0.098213          9.645870e-03     1202.379321
# ...                        ...                   ...             ...
# 54700                      NaN                   NaN     2182.434818
# 54701                 1.558585          2.429186e+00     2182.434818
# 54702                 0.012440          1.547596e-04     2182.434818
# 54703                 7.334411          5.379359e+01     2182.434818
# 54704                      NaN                   NaN     2182.434818
#
#        HHI_production_scaled
# 0                   0.075656
# 1                   0.075656
# 2                   0.075656
# 3                   0.075656
# 4                   0.075656
# ...                      ...
# 54700               0.182702
# 54701               0.182702
# 54702               0.182702
# 54703               0.182702
# 54704               0.182702
#
# [54705 rows x 14 columns]

# %%
df_hhi_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54705 entries, 0 to 54704
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  54705 non-null  object
#  1   Product                  54705 non-null  object
#  2   cmdCode                  30177 non-null  object
#  3   Source                   54705 non-null  object
#  4   Year                     54705 non-null  int64
#  5   Value                    40068 non-null  float64
#  6   Value (Ton)              40068 non-null  float64
#  7   qtyUnitAbbr              54705 non-null  object
#  8   reporterCode             53613 non-null  object
#  9   Total_value_YearProduct  54705 non-null  float64
#  10  Share in % (production)  40068 non-null  float64
#  11  Share HHI Production     40068 non-null  float64
#  12  HHI_production           54705 non-null  float64
#  13  HHI_production_scaled    54705 non-null  float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 5.8+ MB

# %%
df_hhi_exports.loc[df_hhi_exports["reporterCode"].notnull(), 'reporterCode'] = df_hhi_exports.loc[df_hhi_exports['reporterCode'].notnull(), 'reporterCode'].apply(int).apply(str)
df_hhi_exports.loc[df_hhi_exports["cmdCode"].notnull(), 'cmdCode'] = df_hhi_exports.loc[df_hhi_exports['cmdCode'].notnull(), 'cmdCode'].apply(int).apply(str)
df_hhi_exports.rename(columns={"Share in %": "Share in % (exports)"}, inplace=True)
df_hhi_exports
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year reporterCode  \
# 0            C        A     20000101     2000        52  2000           32
# 1            C        A     20000101     2000        52  2000           40
# 2            C        A     20000101     2000        52  2000           56
# 3            C        A     20000101     2000        52  2000           76
# 4            C        A     20000101     2000        52  2000          100
# ...        ...      ...          ...      ...       ...   ...          ...
# 33144        C        A     20200101     2020        52  2020          792
# 33145        C        A     20200101     2020        52  2020          804
# 33146        C        A     20200101     2020        52  2020          826
# 33147        C        A     20200101     2020        52  2020          834
# 33148        C        A     20200101     2020        52  2020          842
#
#       reporterISO             reporterDesc flowCode flowDesc  partnerCode  \
# 0             ARG                Argentina        X   Export            0
# 1             AUT                  Austria        X   Export            0
# 2             BEL                  Belgium        X   Export            0
# 3             BRA                   Brazil        X   Export            0
# 4             BGR                 Bulgaria        X   Export            0
# ...           ...                      ...      ...      ...          ...
# 33144         TUR                  Türkiye        X   Export            0
# 33145         UKR                  Ukraine        X   Export            0
# 33146         GBR           United Kingdom        X   Export            0
# 33147         TZA  United Rep. of Tanzania        X   Export            0
# 33148         USA                      USA        X   Export            0
#
#       partnerISO partnerDesc  partner2Code partner2ISO partner2Desc  \
# 0            W00       World             0         W00        World
# 1            W00       World             0         W00        World
# 2            W00       World             0         W00        World
# 3            W00       World             0         W00        World
# 4            W00       World             0         W00        World
# ...          ...         ...           ...         ...          ...
# 33144        W00       World             0         W00        World
# 33145        W00       World             0         W00        World
# 33146        W00       World             0         W00        World
# 33147        W00       World             0         W00        World
# 33148        W00       World             0         W00        World
#
#       classificationCode classificationSearchCode  isOriginalClassification  \
# 0                     H1                       HS                      True
# 1                     H1                       HS                      True
# 2                     H1                       HS                      True
# 3                     H1                       HS                      True
# 4                     H1                       HS                      True
# ...                  ...                      ...                       ...
# 33144                 H5                       HS                      True
# 33145                 H5                       HS                      True
# 33146                 H5                       HS                      True
# 33147                 H5                       HS                      True
# 33148                 H5                       HS                      True
#
#       cmdCode                          cmdDesc  aggrLevel  isLeaf customsCode  \
# 0        2606  Aluminium ores and concentrates          4   False         C00
# 1        2606  Aluminium ores and concentrates          4   False         C00
# 2        2606  Aluminium ores and concentrates          4   False         C00
# 3        2606  Aluminium ores and concentrates          4   False         C00
# 4        2606  Aluminium ores and concentrates          4   False         C00
# ...       ...                              ...        ...     ...         ...
# 33144  261510  Zirconium ores and concentrates          6    True         C00
# 33145  261510  Zirconium ores and concentrates          6    True         C00
# 33146  261510  Zirconium ores and concentrates          6    True         C00
# 33147  261510  Zirconium ores and concentrates          6    True         C00
# 33148  261510  Zirconium ores and concentrates          6    True         C00
#
#       customsDesc  mosCode  motCode    motDesc  qtyUnitCode qtyUnitAbbr  \
# 0       TOTAL CPC        0        0  TOTAL MOT            8          kg
# 1       TOTAL CPC        0        0  TOTAL MOT            8          kg
# 2       TOTAL CPC        0        0  TOTAL MOT            8          kg
# 3       TOTAL CPC        0        0  TOTAL MOT            8          kg
# 4       TOTAL CPC        0        0  TOTAL MOT            8          kg
# ...           ...      ...      ...        ...          ...         ...
# 33144   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 33145   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 33146   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 33147   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 33148   TOTAL CPC        0        0  TOTAL MOT            8          kg
#
#                qty  isQtyEstimated  altQtyUnitCode altQtyUnitAbbr      altQty  \
# 0          14000.0           False              -1            NaN         NaN
# 1         128800.0           False              -1            NaN         NaN
# 2      133826657.0           False              -1            NaN         NaN
# 3        5135286.0           False               8             kg   5135286.0
# 4         920981.0           False              -1            NaN         NaN
# ...            ...             ...             ...            ...         ...
# 33144      90395.0           False               8             kg     90395.0
# 33145   15980300.0           False               8             kg  15980300.0
# 33146    1223196.0           False               8             kg   1223196.0
# 33147     765000.0           False               8             kg    765000.0
# 33148   20982638.0           False               8             kg  20982638.0
#
#        isAltQtyEstimated        netWgt  isNetWgtEstimated  grossWgt  \
# 0                  False  1.400000e+04              False       NaN
# 1                  False  1.288000e+05              False       NaN
# 2                  False  1.338267e+08              False       NaN
# 3                  False  4.166202e+09              False       0.0
# 4                  False  9.209810e+05              False       NaN
# ...                  ...           ...                ...       ...
# 33144              False  9.039500e+04              False       0.0
# 33145              False  1.598030e+07              False       0.0
# 33146              False  1.223196e+06              False       0.0
# 33147              False  7.650000e+05              False       0.0
# 33148              False  2.098264e+07              False       0.0
#
#        isGrossWgtEstimated  cifvalue      fobvalue  primaryValue  \
# 0                    False       NaN  4.291000e+03  4.291000e+03
# 1                    False       NaN  2.275000e+04  2.275000e+04
# 2                    False       NaN  1.435771e+07  1.435771e+07
# 3                    False       0.0  1.131292e+08  1.131292e+08
# 4                    False       NaN  3.882580e+05  3.882580e+05
# ...                    ...       ...           ...           ...
# 33144                False       0.0  1.611700e+05  1.611700e+05
# 33145                False       0.0  2.064597e+07  2.064597e+07
# 33146                False       0.0  3.896642e+06  3.896642e+06
# 33147                False       0.0  2.295000e+05  2.295000e+05
# 33148                False       0.0  3.562715e+07  3.562715e+07
#
#        legacyEstimationFlag  isReported  isAggregate    Product  \
# 0                         0       False        False  ALUMINIUM
# 1                         0       False        False  ALUMINIUM
# 2                         0       False        False  ALUMINIUM
# 3                         0       False         True  ALUMINIUM
# 4                         0       False        False  ALUMINIUM
# ...                     ...         ...          ...        ...
# 33144                     0       False         True  ZIRCONIUM
# 33145                     0       False         True  ZIRCONIUM
# 33146                     0       False         True  ZIRCONIUM
# 33147                     0       False         True  ZIRCONIUM
# 33148                     0       False         True  ZIRCONIUM
#
#        Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 0                  1.735930e+10              0.000081       6.504168e-09
# 1                  1.735930e+10              0.000742       5.505128e-07
# 2                  1.735930e+10              0.770922       5.943208e-01
# 3                  1.735930e+10             23.999830       5.759918e+02
# 4                  1.735930e+10              0.005305       2.814732e-05
# ...                         ...                   ...                ...
# 33144              5.196047e+08              0.017397       3.026514e-04
# 33145              5.196047e+08              3.075473       9.458533e+00
# 33146              5.196047e+08              0.235409       5.541738e-02
# 33147              5.196047e+08              0.147227       2.167588e-02
# 33148              5.196047e+08              4.038193       1.630700e+01
#
#        HHI_exports  HHI_exports_scaled
# 0      2219.749888            0.164204
# 1      2219.749888            0.164204
# 2      2219.749888            0.164204
# 3      2219.749888            0.164204
# 4      2219.749888            0.164204
# ...            ...                 ...
# 33144  1210.445136            0.052793
# 33145  1210.445136            0.052793
# 33146  1210.445136            0.052793
# 33147  1210.445136            0.052793
# 33148  1210.445136            0.052793
#
# [33149 rows x 53 columns]

# %%
df_hhi_exports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33149 entries, 0 to 33148
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   typeCode                  33149 non-null  object
#  1   freqCode                  33149 non-null  object
#  2   refPeriodId               33149 non-null  int64
#  3   refYear                   33149 non-null  int64
#  4   refMonth                  33149 non-null  int64
#  5   Year                      33149 non-null  int64
#  6   reporterCode              33149 non-null  object
#  7   reporterISO               33149 non-null  object
#  8   reporterDesc              33149 non-null  object
#  9   flowCode                  33149 non-null  object
#  10  flowDesc                  33149 non-null  object
#  11  partnerCode               33149 non-null  int64
#  12  partnerISO                33149 non-null  object
#  13  partnerDesc               33149 non-null  object
#  14  partner2Code              33149 non-null  int64
#  15  partner2ISO               33149 non-null  object
#  16  partner2Desc              33149 non-null  object
#  17  classificationCode        33149 non-null  object
#  18  classificationSearchCode  33149 non-null  object
#  19  isOriginalClassification  33149 non-null  bool
#  20  cmdCode                   33149 non-null  object
#  21  cmdDesc                   33149 non-null  object
#  22  aggrLevel                 33149 non-null  int64
#  23  isLeaf                    33149 non-null  bool
#  24  customsCode               33149 non-null  object
#  25  customsDesc               33149 non-null  object
#  26  mosCode                   33149 non-null  int64
#  27  motCode                   33149 non-null  int64
#  28  motDesc                   33149 non-null  object
#  29  qtyUnitCode               33149 non-null  int64
#  30  qtyUnitAbbr               33148 non-null  object
#  31  qty                       33148 non-null  float64
#  32  isQtyEstimated            33149 non-null  bool
#  33  altQtyUnitCode            33149 non-null  int64
#  34  altQtyUnitAbbr            10767 non-null  object
#  35  altQty                    13356 non-null  float64
#  36  isAltQtyEstimated         33149 non-null  bool
#  37  netWgt                    32778 non-null  float64
#  38  isNetWgtEstimated         33149 non-null  bool
#  39  grossWgt                  10042 non-null  float64
#  40  isGrossWgtEstimated       33149 non-null  bool
#  41  cifvalue                  7054 non-null   float64
#  42  fobvalue                  33149 non-null  float64
#  43  primaryValue              33149 non-null  float64
#  44  legacyEstimationFlag      33149 non-null  int64
#  45  isReported                33149 non-null  bool
#  46  isAggregate               33149 non-null  bool
#  47  Product                   33149 non-null  object
#  48  Total_netWgt_YearProduct  33149 non-null  float64
#  49  Share in % (exports)      32778 non-null  float64
#  50  Share HHI Exports         32778 non-null  float64
#  51  HHI_exports               33149 non-null  float64
#  52  HHI_exports_scaled        33149 non-null  float64
# dtypes: bool(8), float64(12), int64(12), object(21)
# memory usage: 11.6+ MB

# %% [markdown]
# ### Merge both dataframes

# %%
df_hhi_exports["qtyUnitAbbr"].unique()
# Out:
# array(['kg', nan, 'l', 'u'], dtype=object)

# %%
df_hhi_master = pd.merge(df_hhi_production, df_hhi_exports, how="outer", left_on=["Year", "reporterCode", "cmdCode", "qtyUnitAbbr"], right_on=["Year", "reporterCode", "cmdCode", "qtyUnitAbbr"])
df_hhi_master
# Out:
#          Country            Product_x cmdCode Source  Year         Value  \
# 0        ALBANIA  IRON ORE (FE-CONT.)    2601    org  2000  5.000000e+06
# 1        ALGERIA  IRON ORE (FE-CONT.)    2601    org  2000  7.200000e+08
# 2      ARGENTINA  IRON ORE (FE-CONT.)    2601    org  2000  0.000000e+00
# 3      AUSTRALIA  IRON ORE (FE-CONT.)    2601    org  2000  1.077287e+11
# 4        AUSTRIA  IRON ORE (FE-CONT.)    2601    org  2000  5.950240e+08
# ...          ...                  ...     ...    ...   ...           ...
# 71288        NaN                  NaN  261510    NaN  2020           NaN
# 71289        NaN                  NaN  261510    NaN  2020           NaN
# 71290        NaN                  NaN  261510    NaN  2020           NaN
# 71291        NaN                  NaN  261510    NaN  2020           NaN
# 71292        NaN                  NaN  261510    NaN  2020           NaN
#
#        Value (Ton) qtyUnitAbbr reporterCode  Total_value_YearProduct  \
# 0           5000.0          kg            8             6.058481e+11
# 1         720000.0          kg           12             6.058481e+11
# 2              0.0          kg           32             6.058481e+11
# 3      107728740.0          kg           36             6.058481e+11
# 4         595024.0          kg           40             6.058481e+11
# ...            ...         ...          ...                      ...
# 71288          NaN          kg          752                      NaN
# 71289          NaN          kg          757                      NaN
# 71290          NaN          kg          784                      NaN
# 71291          NaN          kg          826                      NaN
# 71292          NaN          kg          834                      NaN
#
#        Share in % (production)  Share HHI Production  HHI_production  \
# 0                     0.000825          6.811025e-07     1202.379321
# 1                     0.118842          1.412334e-02     1202.379321
# 2                     0.000000          0.000000e+00     1202.379321
# 3                    17.781476          3.161809e+02     1202.379321
# 4                     0.098213          9.645870e-03     1202.379321
# ...                        ...                   ...             ...
# 71288                      NaN                   NaN             NaN
# 71289                      NaN                   NaN             NaN
# 71290                      NaN                   NaN             NaN
# 71291                      NaN                   NaN             NaN
# 71292                      NaN                   NaN             NaN
#
#        HHI_production_scaled typeCode freqCode  refPeriodId  refYear  \
# 0                   0.075656      NaN      NaN          NaN      NaN
# 1                   0.075656      NaN      NaN          NaN      NaN
# 2                   0.075656        C        A   20000101.0   2000.0
# 3                   0.075656        C        A   20000101.0   2000.0
# 4                   0.075656        C        A   20000101.0   2000.0
# ...                      ...      ...      ...          ...      ...
# 71288                    NaN        C        A   20200101.0   2020.0
# 71289                    NaN        C        A   20200101.0   2020.0
# 71290                    NaN        C        A   20200101.0   2020.0
# 71291                    NaN        C        A   20200101.0   2020.0
# 71292                    NaN        C        A   20200101.0   2020.0
#
#        refMonth reporterISO             reporterDesc flowCode flowDesc  \
# 0           NaN         NaN                      NaN      NaN      NaN
# 1           NaN         NaN                      NaN      NaN      NaN
# 2          52.0         ARG                Argentina        X   Export
# 3          52.0         AUS                Australia        X   Export
# 4          52.0         AUT                  Austria        X   Export
# ...         ...         ...                      ...      ...      ...
# 71288      52.0         SWE                   Sweden        X   Export
# 71289      52.0         CHE              Switzerland        X   Export
# 71290      52.0         ARE     United Arab Emirates        X   Export
# 71291      52.0         GBR           United Kingdom        X   Export
# 71292      52.0         TZA  United Rep. of Tanzania        X   Export
#
#        partnerCode partnerISO partnerDesc  partner2Code partner2ISO  \
# 0              NaN        NaN         NaN           NaN         NaN
# 1              NaN        NaN         NaN           NaN         NaN
# 2              0.0        W00       World           0.0         W00
# 3              0.0        W00       World           0.0         W00
# 4              0.0        W00       World           0.0         W00
# ...            ...        ...         ...           ...         ...
# 71288          0.0        W00       World           0.0         W00
# 71289          0.0        W00       World           0.0         W00
# 71290          0.0        W00       World           0.0         W00
# 71291          0.0        W00       World           0.0         W00
# 71292          0.0        W00       World           0.0         W00
#
#       partner2Desc classificationCode classificationSearchCode  \
# 0              NaN                NaN                      NaN
# 1              NaN                NaN                      NaN
# 2            World                 H1                       HS
# 3            World                 H1                       HS
# 4            World                 H1                       HS
# ...            ...                ...                      ...
# 71288        World                 H5                       HS
# 71289        World                 H5                       HS
# 71290        World                 H5                       HS
# 71291        World                 H5                       HS
# 71292        World                 H5                       HS
#
#       isOriginalClassification  \
# 0                          NaN
# 1                          NaN
# 2                         True
# 3                         True
# 4                         True
# ...                        ...
# 71288                     True
# 71289                     True
# 71290                     True
# 71291                     True
# 71292                     True
#
#                                                  cmdDesc  aggrLevel isLeaf  \
# 0                                                    NaN        NaN    NaN
# 1                                                    NaN        NaN    NaN
# 2      Iron ores and concentrates; including roasted ...        4.0  False
# 3      Iron ores and concentrates; including roasted ...        4.0  False
# 4      Iron ores and concentrates; including roasted ...        4.0  False
# ...                                                  ...        ...    ...
# 71288                    Zirconium ores and concentrates        6.0   True
# 71289                    Zirconium ores and concentrates        6.0   True
# 71290                    Zirconium ores and concentrates        6.0   True
# 71291                    Zirconium ores and concentrates        6.0   True
# 71292                    Zirconium ores and concentrates        6.0   True
#
#       customsCode customsDesc  mosCode  motCode    motDesc  qtyUnitCode  \
# 0             NaN         NaN      NaN      NaN        NaN          NaN
# 1             NaN         NaN      NaN      NaN        NaN          NaN
# 2             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 3             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 4             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# ...           ...         ...      ...      ...        ...          ...
# 71288         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 71289         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 71290         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 71291         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 71292         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
#
#                 qty isQtyEstimated  altQtyUnitCode altQtyUnitAbbr     altQty  \
# 0               NaN            NaN             NaN            NaN        NaN
# 1               NaN            NaN             NaN            NaN        NaN
# 2      6.811000e+04          False            -1.0            NaN        NaN
# 3      1.652031e+11          False            -1.0            NaN        NaN
# 4      2.800000e+03          False            -1.0            NaN        NaN
# ...             ...            ...             ...            ...        ...
# 71288  4.570543e+04           True            -1.0            NaN        0.0
# 71289  2.500000e+01           True            -1.0            NaN        0.0
# 71290  8.278620e+05          False             8.0             kg   827862.0
# 71291  1.223196e+06          False             8.0             kg  1223196.0
# 71292  7.650000e+05          False             8.0             kg   765000.0
#
#       isAltQtyEstimated        netWgt isNetWgtEstimated  grossWgt  \
# 0                   NaN           NaN               NaN       NaN
# 1                   NaN           NaN               NaN       NaN
# 2                 False  6.811000e+04             False       NaN
# 3                 False  1.652031e+11             False       NaN
# 4                 False  2.800000e+03             False       NaN
# ...                 ...           ...               ...       ...
# 71288             False  4.570543e+04              True       0.0
# 71289             False  2.500000e+01              True       0.0
# 71290             False  8.278620e+05             False       0.0
# 71291             False  1.223196e+06             False       0.0
# 71292             False  7.650000e+05             False       0.0
#
#       isGrossWgtEstimated  cifvalue      fobvalue  primaryValue  \
# 0                     NaN       NaN           NaN           NaN
# 1                     NaN       NaN           NaN           NaN
# 2                   False       NaN  1.093500e+04  1.093500e+04
# 3                   False       NaN  2.560404e+09  2.560404e+09
# 4                   False       NaN  1.340000e+02  1.340000e+02
# ...                   ...       ...           ...           ...
# 71288               False       0.0  2.909783e+04  2.909783e+04
# 71289               False       0.0  2.665140e+02  2.665140e+02
# 71290               False       0.0  1.421075e+06  1.421075e+06
# 71291               False       0.0  3.896642e+06  3.896642e+06
# 71292               False       0.0  2.295000e+05  2.295000e+05
#
#        legacyEstimationFlag isReported isAggregate  Product_y  \
# 0                       NaN        NaN         NaN        NaN
# 1                       NaN        NaN         NaN        NaN
# 2                       0.0      False       False       IRON
# 3                       0.0      False       False       IRON
# 4                       0.0      False       False       IRON
# ...                     ...        ...         ...        ...
# 71288                   6.0      False        True  ZIRCONIUM
# 71289                   6.0      False        True  ZIRCONIUM
# 71290                   0.0      False        True  ZIRCONIUM
# 71291                   0.0      False        True  ZIRCONIUM
# 71292                   0.0      False        True  ZIRCONIUM
#
#        Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 0                           NaN                   NaN                NaN
# 1                           NaN                   NaN                NaN
# 2                  2.743603e+11              0.000025       6.162818e-10
# 3                  2.743603e+11             60.213923       3.625716e+03
# 4                  2.743603e+11              0.000001       1.041534e-12
# ...                         ...                   ...                ...
# 71288              5.196047e+08              0.008796       7.737300e-05
# 71289              5.196047e+08              0.000005       2.314909e-11
# 71290              5.196047e+08              0.159325       2.538457e-02
# 71291              5.196047e+08              0.235409       5.541738e-02
# 71292              5.196047e+08              0.147227       2.167588e-02
#
#        HHI_exports  HHI_exports_scaled
# 0              NaN                 NaN
# 1              NaN                 NaN
# 2      3836.182057            0.342631
# 3      3836.182057            0.342631
# 4      3836.182057            0.342631
# ...            ...                 ...
# 71288  1210.445136            0.052793
# 71289  1210.445136            0.052793
# 71290  1210.445136            0.052793
# 71291  1210.445136            0.052793
# 71292  1210.445136            0.052793
#
# [71293 rows x 63 columns]

# %%
# Data that contains HHI production and Exports
df_hhi_master[~(df_hhi_master["HHI_exports"].isna()) & ~(df_hhi_master["HHI_production"].isna())]
# Out:
#             Country             Product_x cmdCode Source  Year         Value  \
# 2         ARGENTINA   IRON ORE (FE-CONT.)    2601    org  2000  0.000000e+00
# 3         AUSTRALIA   IRON ORE (FE-CONT.)    2601    org  2000  1.077287e+11
# 4           AUSTRIA   IRON ORE (FE-CONT.)    2601    org  2000  5.950240e+08
# 10         BULGARIA   IRON ORE (FE-CONT.)    2601    org  2000  3.041000e+08
# 11           CANADA   IRON ORE (FE-CONT.)    2601    org  2000  2.178100e+10
# ...             ...                   ...     ...    ...   ...           ...
# 54662         NIGER  URANIUM (U3O8-CONT.)  261210    org  2019  3.516000e+06
# 54667  SOUTH AFRICA  URANIUM (U3O8-CONT.)  261210    org  2019  1.630000e+05
# 54682        FRANCE  URANIUM (U3O8-CONT.)  261210    org  2020           NaN
# 54694         NIGER  URANIUM (U3O8-CONT.)  261210    org  2020  3.527000e+06
# 54701       UKRAINE  URANIUM (U3O8-CONT.)  261210    org  2020  8.770000e+05
#
#        Value (Ton) qtyUnitAbbr reporterCode  Total_value_YearProduct  \
# 2              0.0          kg           32             6.058481e+11
# 3      107728740.0          kg           36             6.058481e+11
# 4         595024.0          kg           40             6.058481e+11
# 10        304100.0          kg          100             6.058481e+11
# 11      21781000.0          kg          124             6.058481e+11
# ...            ...         ...          ...                      ...
# 54662       3516.0          kg          562             6.427800e+07
# 54667        163.0          kg          710             6.427800e+07
# 54682          NaN          kg          251             5.626900e+07
# 54694       3527.0          kg          562             5.626900e+07
# 54701        877.0          kg          804             5.626900e+07
#
#        Share in % (production)  Share HHI Production  HHI_production  \
# 2                     0.000000              0.000000     1202.379321
# 3                    17.781476            316.180885     1202.379321
# 4                     0.098213              0.009646     1202.379321
# 10                    0.050194              0.002519     1202.379321
# 11                    3.595125             12.924926     1202.379321
# ...                        ...                   ...             ...
# 54662                 5.469990             29.920788     2274.305780
# 54667                 0.253586              0.064306     2274.305780
# 54682                      NaN                   NaN     2182.434818
# 54694                 6.268105             39.289140     2182.434818
# 54701                 1.558585              2.429186     2182.434818
#
#        HHI_production_scaled typeCode freqCode  refPeriodId  refYear  \
# 2                   0.075656        C        A   20000101.0   2000.0
# 3                   0.075656        C        A   20000101.0   2000.0
# 4                   0.075656        C        A   20000101.0   2000.0
# 10                  0.075656        C        A   20000101.0   2000.0
# 11                  0.075656        C        A   20000101.0   2000.0
# ...                      ...      ...      ...          ...      ...
# 54662               0.192737        C        A   20190101.0   2019.0
# 54667               0.192737        C        A   20190101.0   2019.0
# 54682               0.182702        C        A   20200101.0   2020.0
# 54694               0.182702        C        A   20200101.0   2020.0
# 54701               0.182702        C        A   20200101.0   2020.0
#
#        refMonth reporterISO  reporterDesc flowCode flowDesc  partnerCode  \
# 2          52.0         ARG     Argentina        X   Export          0.0
# 3          52.0         AUS     Australia        X   Export          0.0
# 4          52.0         AUT       Austria        X   Export          0.0
# 10         52.0         BGR      Bulgaria        X   Export          0.0
# 11         52.0         CAN        Canada        X   Export          0.0
# ...         ...         ...           ...      ...      ...          ...
# 54662      52.0         NER         Niger        X   Export          0.0
# 54667      52.0         ZAF  South Africa        X   Export          0.0
# 54682      52.0         FRA        France        X   Export          0.0
# 54694      52.0         NER         Niger        X   Export          0.0
# 54701      52.0         UKR       Ukraine        X   Export          0.0
#
#       partnerISO partnerDesc  partner2Code partner2ISO partner2Desc  \
# 2            W00       World           0.0         W00        World
# 3            W00       World           0.0         W00        World
# 4            W00       World           0.0         W00        World
# 10           W00       World           0.0         W00        World
# 11           W00       World           0.0         W00        World
# ...          ...         ...           ...         ...          ...
# 54662        W00       World           0.0         W00        World
# 54667        W00       World           0.0         W00        World
# 54682        W00       World           0.0         W00        World
# 54694        W00       World           0.0         W00        World
# 54701        W00       World           0.0         W00        World
#
#       classificationCode classificationSearchCode isOriginalClassification  \
# 2                     H1                       HS                     True
# 3                     H1                       HS                     True
# 4                     H1                       HS                     True
# 10                    H1                       HS                     True
# 11                    H1                       HS                     True
# ...                  ...                      ...                      ...
# 54662                 H5                       HS                     True
# 54667                 H5                       HS                     True
# 54682                 H5                       HS                     True
# 54694                 H5                       HS                     True
# 54701                 H5                       HS                     True
#
#                                                  cmdDesc  aggrLevel isLeaf  \
# 2      Iron ores and concentrates; including roasted ...        4.0  False
# 3      Iron ores and concentrates; including roasted ...        4.0  False
# 4      Iron ores and concentrates; including roasted ...        4.0  False
# 10     Iron ores and concentrates; including roasted ...        4.0  False
# 11     Iron ores and concentrates; including roasted ...        4.0  False
# ...                                                  ...        ...    ...
# 54662                      Uranium ores and concentrates        6.0   True
# 54667                      Uranium ores and concentrates        6.0   True
# 54682                      Uranium ores and concentrates        6.0   True
# 54694                      Uranium ores and concentrates        6.0   True
# 54701                      Uranium ores and concentrates        6.0   True
#
#       customsCode customsDesc  mosCode  motCode    motDesc  qtyUnitCode  \
# 2             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 3             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 4             C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 10            C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 11            C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# ...           ...         ...      ...      ...        ...          ...
# 54662         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 54667         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 54682         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 54694         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
# 54701         C00   TOTAL CPC      0.0      0.0  TOTAL MOT          8.0
#
#                 qty isQtyEstimated  altQtyUnitCode altQtyUnitAbbr     altQty  \
# 2      6.811000e+04          False            -1.0            NaN        NaN
# 3      1.652031e+11          False            -1.0            NaN        NaN
# 4      2.800000e+03          False            -1.0            NaN        NaN
# 10     2.938059e+07          False            -1.0            NaN        NaN
# 11     2.657139e+07          False            -1.0            NaN        NaN
# ...             ...            ...             ...            ...        ...
# 54662  3.718563e+06           True            -1.0            NaN        0.0
# 54667  4.050000e+02          False            -1.0            NaN        0.0
# 54682  1.500000e+01          False             8.0             kg       15.0
# 54694  4.314254e+06          False             8.0             kg  4314254.0
# 54701  2.000000e-01          False             8.0             kg        0.2
#
#       isAltQtyEstimated        netWgt isNetWgtEstimated  grossWgt  \
# 2                 False  6.811000e+04             False       NaN
# 3                 False  1.652031e+11             False       NaN
# 4                 False  2.800000e+03             False       NaN
# 10                False  2.938059e+07             False       NaN
# 11                False  2.657139e+07             False       NaN
# ...                 ...           ...               ...       ...
# 54662             False  3.718563e+06              True       0.0
# 54667             False  4.050000e+02             False       0.0
# 54682             False  1.500000e+01             False       0.0
# 54694             False  4.314254e+06             False       0.0
# 54701             False  2.000000e-01             False       0.0
#
#       isGrossWgtEstimated  cifvalue      fobvalue  primaryValue  \
# 2                   False       NaN  1.093500e+04  1.093500e+04
# 3                   False       NaN  2.560404e+09  2.560404e+09
# 4                   False       NaN  1.340000e+02  1.340000e+02
# 10                  False       NaN  4.448640e+05  4.448640e+05
# 11                  False       NaN  7.137159e+08  7.137159e+08
# ...                   ...       ...           ...           ...
# 54662               False       0.0  2.265856e+08  2.265856e+08
# 54667               False       0.0  2.440870e+03  2.440870e+03
# 54682               False       0.0  1.819260e+02  1.819260e+02
# 54694               False       0.0  2.847365e+08  2.847365e+08
# 54701               False       0.0  2.329000e+01  2.329000e+01
#
#        legacyEstimationFlag isReported isAggregate Product_y  \
# 2                       0.0      False       False      IRON
# 3                       0.0      False       False      IRON
# 4                       0.0      False       False      IRON
# 10                      0.0      False       False      IRON
# 11                      0.0      False       False      IRON
# ...                     ...        ...         ...       ...
# 54662                   6.0      False        True   URANIUM
# 54667                   0.0      False        True   URANIUM
# 54682                   0.0      False        True   URANIUM
# 54694                   0.0      False        True   URANIUM
# 54701                   0.0      False        True   URANIUM
#
#        Total_netWgt_YearProduct  Share in % (exports)  Share HHI Exports  \
# 2                  2.743603e+11              0.000025       6.162818e-10
# 3                  2.743603e+11             60.213923       3.625716e+03
# 4                  2.743603e+11              0.000001       1.041534e-12
# 10                 2.743603e+11              0.010709       1.146776e-04
# 11                 2.743603e+11              0.009685       9.379642e-05
# ...                         ...                   ...                ...
# 54662              1.543013e+07             24.099363       5.807793e+02
# 54667              1.543013e+07              0.002625       6.889232e-06
# 54682              6.182528e+06              0.000243       5.886407e-08
# 54694              6.182528e+06             69.781388       4.869442e+03
# 54701              6.182528e+06              0.000003       1.046472e-11
#
#        HHI_exports  HHI_exports_scaled
# 2      3836.182057            0.342631
# 3      3836.182057            0.342631
# 4      3836.182057            0.342631
# 10     3836.182057            0.342631
# 11     3836.182057            0.342631
# ...            ...                 ...
# 54662  6335.012663            0.618461
# 54667  6335.012663            0.618461
# 54682  5782.582977            0.557482
# 54694  5782.582977            0.557482
# 54701  5782.582977            0.557482
#
# [16723 rows x 63 columns]

# %%
df_hhi_exports[(df_hhi_exports["Year"]==2016) & (df_hhi_exports["reporterDesc"] == "China")] # ALUMINUM DOES NOT EXIST FOR CHINA,2016

# %%
df_hhi_exports[(df_hhi_exports["Year"]==2009) & (df_hhi_exports["reporterDesc"] == "Croatia")] # ALUMINUM DOES NOT EXIST FOR CROATIA,2009
# Out:
#       typeCode freqCode  refPeriodId  refYear  refMonth  Year reporterCode  \
# 13083        C        A     20090101     2009        52  2009          191
# 13286        C        A     20090101     2009        52  2009          191
# 13491        C        A     20090101     2009        52  2009          191
# 13600        C        A     20090101     2009        52  2009          191
# 14087        C        A     20090101     2009        52  2009          191
#
#       reporterISO reporterDesc flowCode  ...   fobvalue  primaryValue  \
# 13083         HRV      Croatia        X  ...     9777.0        9777.0
# 13286         HRV      Croatia        X  ...    10117.0       10117.0
# 13491         HRV      Croatia        X  ...  3473804.0     3473804.0
# 13600         HRV      Croatia        X  ...     4581.0        4581.0
# 14087         HRV      Croatia        X  ...   437505.0      437505.0
#
#       legacyEstimationFlag isReported  isAggregate      Product  \
# 13083                    0       True        False      BARYTES
# 13286                    0       True        False         COAL
# 13491                    0       True        False         GOLD
# 13600                    0       True        False     GRAPHITE
# 14087                    0       True        False  NATURAL GAS
#
#       Total_netWgt_YearProduct Share in % (exports) Share HHI Exports  \
# 13083             3.581624e+09         1.423935e-04      2.027591e-08
# 13286             9.556307e+11         5.347254e-08      2.859312e-15
# 13491             1.910489e+07         7.327965e-04      5.369907e-07
# 13600             5.681944e+08         1.839159e-04      3.382506e-08
# 14087             1.302709e+11         5.712951e-04      3.263781e-07
#
#        HHI_exports
# 13083  3146.684482
# 13286  1727.556377
# 13491  3611.730996
# 13600  6551.476056
# 14087  1253.800340
#
# [5 rows x 52 columns]

# %%
df_hhi_master[(df_hhi_master["Year"]==2016) & (df_hhi_master["Country"] == "CHINA")]

# %%
df_hhi_master[(df_hhi_master["Year"]==2009) & (df_hhi_master["Country"] == "CROATIA")]
# Out:
#        Year  Country  Value    Product reporterCode reporterDesc_x  \
# 294    2009  CROATIA  500.0  ALUMINIUM          191        CROATIA
# 6720   2009  CROATIA    NaN    BARYTES          191        CROATIA
# 47963  2009  CROATIA    NaN     SILVER          191        CROATIA
#
#        Total_value_YearProduct  Share in % (production)  Share HHI Production  \
# 294                197735840.0                 0.000253          6.393950e-08
# 6720                 7662051.0                      NaN                   NaN
# 47963               22322463.0                      NaN                   NaN
#
#        HHI_production  ... cifvalue fobvalue  primaryValue  \
# 294       1713.133234  ...      NaN      NaN           NaN
# 6720      2359.851398  ...      NaN   9777.0        9777.0
# 47963      981.801726  ...      NaN      NaN           NaN
#
#        legacyEstimationFlag  isReported isAggregate Total_netWgt_YearProduct  \
# 294                     NaN         NaN         NaN                      NaN
# 6720                    0.0        True       False             3.581624e+09
# 47963                   NaN         NaN         NaN                      NaN
#
#       Share in % (exports) Share HHI Exports  HHI_exports
# 294                    NaN               NaN          NaN
# 6720              0.000142      2.027591e-08  3146.684482
# 47963                  NaN               NaN          NaN
#
# [3 rows x 59 columns]

# %%
df_hhi_master.to_csv("../../data/hhi_data/df_hhi_master.csv", index=False)
