# %%
from geopol_client_noAPI import GeopolriskConsumer

# %%
gprc = GeopolriskConsumer()
# Out:
# c:\Users\zacat\OneDrive\Documentos\Investigacion\investigacion-gnn-cic\rb_venv3715\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (1,3,4,6,8,10,12,14,16,18,23,28,29,33,34,35,36,38,39,41,42,43,44,45,46,48,49,50,53,55,57,59,61,63,65,70,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\zacat\\OneDrive\\Documentos\\irune-api-consumption\\Dev'

# %%
# Format (country, product, year)
list_parameters = [
    ("Canada", "Lithium", 2019),
    ("Mexico", "Petroleum", 2019),
    ("USA", "Gold", 2020)
]

# list_parameters = [
#     ("Canada", "Lithium", 2010),
#     ("Canada", "Lithium", 2011),
#     ("Canada", "Lithium", 2012),
#     ("Canada", "Lithium", 2013),
#     ("Canada", "Lithium", 2014),
#     ("Canada", "Lithium", 2015),
#     ("Canada", "Lithium", 2016),
#     ("Canada", "Lithium", 2017),
#     ("Canada", "Lithium", 2018),
#     ("Canada", "Lithium", 2019),
#     ("Canada", "Lithium", 2020),
# ]

# list_parameters = [
#     # ("Canada", "Lithium", 2015),
#     ("USA", "Lithium", 2015),
#     # ("Mexico", "Lithium", 2019)
# ]

# %%
total_result_df, total_condensed_result_df = gprc.get_geopol_risk(list_parameters)
# result_df = gprc.get_geopol_risk(list_parameters)

# %%
total_result_df
# Out:
#          Year Country  Domestic Production Value (P_AC)  Product ISO3  \
# 99738  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 99739  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 99740  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 99741  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 99742  2019.0  CANADA                            9000.0  LITHIUM  CAN
# ...       ...     ...                               ...      ...  ...
# 67772  2020.0     USA                          200000.0     GOLD  USA
# 67773  2020.0     USA                          200000.0     GOLD  USA
# 67774  2020.0     USA                          200000.0     GOLD  USA
# 67775  2020.0     USA                          200000.0     GOLD  USA
# 67776  2020.0     USA                          200000.0     GOLD  USA
#
#        value_economic no_value_economic  value_governance no_value_governance  \
# 99738        0.585179             False          0.819996               False
# 99739        0.585179             False          0.819996               False
# 99740        0.585179             False          0.819996               False
# 99741        0.585179             False          0.819996               False
# 99742        0.585179             False          0.819996               False
# ...               ...               ...               ...                 ...
# 67772        0.613565             False          0.693259               False
# 67773        0.613565             False          0.693259               False
# 67774        0.613565             False          0.693259               False
# 67775        0.613565             False          0.693259               False
# 67776        0.613565             False          0.693259               False
#
#        value_social  ...  HHI_exports       partnerDesc_import  \
# 99738      0.568315  ...  5172.054120                Argentina
# 99739      0.568315  ...  5172.054120                  Austria
# 99740      0.568315  ...  5172.054120                  Belgium
# 99741      0.568315  ...  5172.054120                    Chile
# 99742      0.568315  ...  5172.054120                    China
# ...             ...  ...          ...                      ...
# 67772      0.653018  ...   844.255055           United Kingdom
# 67773      0.653018  ...   844.255055  United Rep. of Tanzania
# 67774      0.653018  ...   844.255055                  Uruguay
# 67775      0.653018  ...   844.255055                Venezuela
# 67776      0.653018  ...   844.255055                   Zambia
#
#       partnerISO_import  netWgt_import netWgt_total_import  \
# 99738               ARG      76542.000         1978337.172
# 99739               AUT     159423.000         1978337.172
# 99740               BEL          6.000         1978337.172
# 99741               CHL    1349466.172         1978337.172
# 99742               CHN     162452.000         1978337.172
# ...                 ...            ...                 ...
# 67772               GBR       7471.319          636658.218
# 67773               TZA         55.053          636658.218
# 67774               URY         36.067          636658.218
# 67775               VEN         79.588          636658.218
# 67776               ZMB          1.930          636658.218
#
#        Geopolitical Risk Production Geopolitical Risk Exports  \
# 99738                  5.779970e-10              4.175101e-10
# 99739                  1.203862e-09              8.695972e-10
# 99740                  4.530823e-14              3.272792e-14
# 99741                  1.019032e-08              7.360870e-09
# 99742                  1.226735e-09              8.861193e-10
# ...                             ...                       ...
# 67772                  1.714240e-11              2.025117e-11
# 67773                  1.263151e-13              1.492223e-13
# 67774                  8.275313e-14              9.776037e-14
# 67775                  1.826089e-13              2.157250e-13
# 67776                  4.428246e-15              5.231306e-15
#
#        Geopolitical Risk Only Political Stability  \
# 99738                                   75.673673
# 99739                                  157.614434
# 99740                                    0.005932
# 99741                                 1334.157225
# 99742                                  160.609072
# ...                                           ...
# 67772                                    1.117051
# 67773                                    0.008231
# 67774                                    0.005392
# 67775                                    0.011899
# 67776                                    0.000289
#
#       Geopolitical Risk Production NO-ROOT  Geopolitical Risk Exports NO-ROOT
# 99738                             1.779900                           1.285692
# 99739                             3.707207                           2.677862
# 99740                             0.000140                           0.000101
# 99741                            31.380355                          22.667268
# 99742                             3.777643                           2.728741
# ...                                    ...                                ...
# 67772                             0.024617                           0.029081
# 67773                             0.000181                           0.000214
# 67774                             0.000119                           0.000140
# 67775                             0.000262                           0.000310
# 67776                             0.000006                           0.000008
#
# [80 rows x 45 columns]

# %%
total_result_df.to_csv("../data/results/resultados_desglose_noAPI.csv")

# %%
total_condensed_result_df
# Out:
#      Product Country    Year   cmdCode  Geopolitical Risk Production  \
# 0    LITHIUM  CANADA  2019.0  283691.0                  1.493916e-08
# 0  PETROLEUM  MEXICO  2019.0    2709.0                  0.000000e+00
# 0       GOLD     USA  2020.0    7108.0                  1.460766e-09
#
#    Geopolitical Risk Exports  Geopolitical Risk Only Political Stability  \
# 0               1.079114e-08                                 1955.894031
# 0               0.000000e+00                                    0.000000
# 0               1.725676e-09                                   95.187966
#
#    Geopolitical Risk Production NO-ROOT  Geopolitical Risk Exports NO-ROOT
# 0                             46.004060                          33.230547
# 0                              0.000000                           0.000000
# 0                              2.097674                           2.478087

# %%
total_condensed_result_df.to_csv("../data/results/resultados_condensado_noAPI.csv")
