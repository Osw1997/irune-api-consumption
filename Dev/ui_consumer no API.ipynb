# %%
from geopol_client_noAPI import GeopolriskConsumer

# %%
gprc = GeopolriskConsumer()
# Out:
# c:\Users\zacat\OneDrive\Documentos\Investigacion\investigacion-gnn-cic\rb_venv3715\lib\site-packages\ipykernel_launcher.py:1: DtypeWarning: Columns (1,3,4,6,8,10,12,14,16,18,23,28,29,33,34,35,36,38,39,41,42,43,44,45,46,48,49,50,53,55,57,59,61,63,65,70,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\zacat\\OneDrive\\Documentos\\irune-api-consumption\\Dev'

# %%
# Format (country, product, year)
list_parameters = [
    ("Canada", "Lithium", 2019),
    ("Mexico", "Petroleum", 2019),
    ("USA", "Gold", 2020)
]

# list_parameters = [
#     ("Canada", "Lithium", 2010),
#     ("Canada", "Lithium", 2011),
#     ("Canada", "Lithium", 2012),
#     ("Canada", "Lithium", 2013),
#     ("Canada", "Lithium", 2014),
#     ("Canada", "Lithium", 2015),
#     ("Canada", "Lithium", 2016),
#     ("Canada", "Lithium", 2017),
#     ("Canada", "Lithium", 2018),
#     ("Canada", "Lithium", 2019),
#     ("Canada", "Lithium", 2020),
# ]

# list_parameters = [
#     # ("Canada", "Lithium", 2015),
#     ("USA", "Lithium", 2015),
#     # ("Mexico", "Lithium", 2019)
# ]

# %%
total_result_df, total_condensed_result_df = gprc.get_geopol_risk(list_parameters)
# result_df = gprc.get_geopol_risk(list_parameters)

# %%
total_result_df
# Out:
#           Year Country  Domestic Production Value (P_AC)  Product ISO3  \
# 108684  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 108685  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 108686  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 108687  2019.0  CANADA                            9000.0  LITHIUM  CAN
# 108688  2019.0  CANADA                            9000.0  LITHIUM  CAN
# ...        ...     ...                               ...      ...  ...
# 73966   2020.0     USA                          200000.0     GOLD  USA
# 73967   2020.0     USA                          200000.0     GOLD  USA
# 73968   2020.0     USA                          200000.0     GOLD  USA
# 73969   2020.0     USA                          200000.0     GOLD  USA
# 73970   2020.0     USA                          200000.0     GOLD  USA
#
#         value_economic no_value_economic  value_governance  \
# 108684        0.585179             False          0.819996
# 108685        0.585179             False          0.819996
# 108686        0.585179             False          0.819996
# 108687        0.585179             False          0.819996
# 108688        0.585179             False          0.819996
# ...                ...               ...               ...
# 73966         0.613565             False          0.693259
# 73967         0.613565             False          0.693259
# 73968         0.613565             False          0.693259
# 73969         0.613565             False          0.693259
# 73970         0.613565             False          0.693259
#
#        no_value_governance  value_social  ...  HHI_exports  \
# 108684               False      0.568315  ...  5172.054120
# 108685               False      0.568315  ...  5172.054120
# 108686               False      0.568315  ...  5172.054120
# 108687               False      0.568315  ...  5172.054120
# 108688               False      0.568315  ...  5172.054120
# ...                    ...           ...  ...          ...
# 73966                False      0.653018  ...   844.255055
# 73967                False      0.653018  ...   844.255055
# 73968                False      0.653018  ...   844.255055
# 73969                False      0.653018  ...   844.255055
# 73970                False      0.653018  ...   844.255055
#
#              partnerDesc_import partnerISO_import  netWgt_import  \
# 108684                Argentina               ARG      76542.000
# 108685                  Austria               AUT     159423.000
# 108686                  Belgium               BEL          6.000
# 108687                    Chile               CHL    1349466.172
# 108688                    China               CHN     162452.000
# ...                         ...               ...            ...
# 73966            United Kingdom               GBR       7471.319
# 73967   United Rep. of Tanzania               TZA         55.053
# 73968                   Uruguay               URY         36.067
# 73969                 Venezuela               VEN         79.588
# 73970                    Zambia               ZMB          1.930
#
#        netWgt_total_import  Geopolitical Risk Production  \
# 108684         1978337.172                  5.779970e-10
# 108685         1978337.172                  1.203862e-09
# 108686         1978337.172                  4.530823e-14
# 108687         1978337.172                  1.019032e-08
# 108688         1978337.172                  1.226735e-09
# ...                    ...                           ...
# 73966           636658.218                  1.714240e-11
# 73967           636658.218                  1.263151e-13
# 73968           636658.218                  8.275313e-14
# 73969           636658.218                  1.826089e-13
# 73970           636658.218                  4.428246e-15
#
#        Geopolitical Risk Exports  Geopolitical Risk Only Political Stability  \
# 108684              4.175101e-10                                   75.673673
# 108685              8.695972e-10                                  157.614434
# 108686              3.272792e-14                                    0.005932
# 108687              7.360870e-09                                 1334.157225
# 108688              8.861193e-10                                  160.609072
# ...                          ...                                         ...
# 73966               2.025117e-11                                    1.117051
# 73967               1.492223e-13                                    0.008231
# 73968               9.776037e-14                                    0.005392
# 73969               2.157250e-13                                    0.011899
# 73970               5.231306e-15                                    0.000289
#
#        Geopolitical Risk Production NO-ROOT  Geopolitical Risk Exports NO-ROOT
# 108684                             1.779900                           1.285692
# 108685                             3.707207                           2.677862
# 108686                             0.000140                           0.000101
# 108687                            31.380355                          22.667268
# 108688                             3.777643                           2.728741
# ...                                     ...                                ...
# 73966                              0.024617                           0.029081
# 73967                              0.000181                           0.000214
# 73968                              0.000119                           0.000140
# 73969                              0.000262                           0.000310
# 73970                              0.000006                           0.000008
#
# [80 rows x 45 columns]

# %%
total_result_df.to_csv("../data/results/resultados_desglose_noAPI.csv")

# %%
total_condensed_result_df
# Out:
#      Product Country    Year   cmdCode  Geopolitical Risk Production  \
# 0    LITHIUM  CANADA  2019.0  283691.0                  1.493916e-08
# 0  PETROLEUM  MEXICO  2019.0    2709.0                  0.000000e+00
# 0       GOLD     USA  2020.0    7108.0                  1.460766e-09
#
#    Geopolitical Risk Exports  Geopolitical Risk Only Political Stability  \
# 0               1.079114e-08                                 1955.894031
# 0               0.000000e+00                                    0.000000
# 0               1.725676e-09                                   95.187966
#
#    Geopolitical Risk Production NO-ROOT  Geopolitical Risk Exports NO-ROOT
# 0                             46.004060                          33.230547
# 0                              0.000000                           0.000000
# 0                              2.097674                           2.478087

# %%
total_condensed_result_df.to_csv("../data/results/resultados_condensado_noAPI.csv")
